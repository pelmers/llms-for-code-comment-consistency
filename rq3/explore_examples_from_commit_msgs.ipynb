# %%
# Data comes from script get create_dataset.py
# DATA_FILENAME = "data/repos-cleaned-TypeScript-2023-06-05-1620.pkl"
# DATA_FILENAME = "data/repos-cleaned-JavaScript-2023-06-05-1933.pkl"
DATA_FILENAME = "data/repos-cleaned-Go-2023-06-05-1432.pkl"

# Note that javascript needs to come before java because java would always match whatever Js matches
LANGUAGE = [l for l in ['Go', 'JavaScript', 'TypeScript', 'Java', 'Python'] if l in DATA_FILENAME][0]

TOP_N = 50

# %%
from tqdm import tqdm
import pandas as pd
import matplotlib.pyplot as plt
import pickle
# Import memoize cache (lru with size = 1)
from functools import lru_cache

@lru_cache(maxsize=1)
def get_comments_df():
    with open(DATA_FILENAME, 'rb') as f:
        all_examples, metadata = pickle.load(f)
        all_examples = [e for es in all_examples.values() for e in es]
        return pd.DataFrame(all_examples)

print(f'Loading data from {DATA_FILENAME} for language {LANGUAGE}...')
comments_df = get_comments_df()

print('Total comments: {}'.format(len(comments_df)))
# Print first 5 rows
comments_df.head()
# Out:
# Loading data from data/repos-cleaned-TypeScript-2023-06-05-1620.pkl for language TypeScript...
# Total comments: 3991
#                               old_entire_comment_raw  \
# 0  /**\n * This method creates an observable that...
# 1  /**\n * This method parses all the fields in t...
# 2  /**\n * Verify (asynchronously) an already dec...
# 3  /**\n * Verify (synchronously) an already deco...
# 4  /**\n * Verify (synchronously) a JWT that is s...
#
#                               new_entire_comment_raw  \
# 0  /**\n * This method creates an observable that...
# 1  /**\n * This method parses all the fields in t...
# 2  /**\n * Verify (asynchronously) an already dec...
# 3  /**\n * Verify (synchronously) an already deco...
# 4  /**\n * Verify (synchronously) a JWT that is s...
#
#                                         old_code_raw  \
# 0  waitForCollectionToLoad() {\n  return this.sto...
# 1  prepareMessage(): string {\n        let messag...
# 2  protected verifyDecomposedJwt(\n  decomposedJw...
# 3  protected verifyDecomposedJwtSync(\n  decompos...
# 4  public verifySync(\n  ...[jwt, properties]: Ve...
#
#                                         new_code_raw  \
# 0  waitForCollectionToLoad() {\n  return this.sto...
# 1  prepareMessage(): string {\n        let messag...
# 2  protected verifyDecomposedJwt(\n  decomposedJw...
# 3  protected verifyDecomposedJwtSync(\n  decompos...
# 4  public verifySync(\n  ...[jwt, properties]: Ve...
#
#                                      old_comment_raw  \
# 0  This method creates an observable that waits f...
# 1  This method parses all the fields in the objec...
# 2  Verify (asynchronously) an already decomposed ...
# 3  Verify (synchronously) an already decomposed J...
# 4  Verify (synchronously) a JWT that is signed us...
#
#                                      new_comment_raw  old_code_start_line  \
# 0  This method creates an observable that waits f...                   33
# 1  This method parses all the fields in the objec...                  152
# 2  Verify (asynchronously) an already decomposed ...                  590
# 3  Verify (synchronously) an already decomposed J...                  551
# 4  Verify (synchronously) a JWT that is signed us...                  531
#
#    old_code_start_char  new_code_start_line  new_code_start_char  ...  \
# 0                    2                   34                    2  ...
# 1                    1                  153                    1  ...
# 2                    2                  600                    2  ...
# 3                    2                  561                    2  ...
# 4                    2                  541                    2  ...
#
#    new_comment_start_char           qualified_name     type  label  \
# 0                       2  waitForCollectionToLoad  summary      1
# 1                       1           prepareMessage  summary      1
# 2                       2      verifyDecomposedJwt  summary      1
# 3                       2  verifyDecomposedJwtSync  summary      1
# 4                       2               verifySync  summary      1
#
#                                         repo_url                         path  \
# 0        https://github.com/ngrx/example-app.git    src/guards/book-exists.ts
# 1           https://github.com/spruceid/siwe.git  packages/siwe/lib/client.ts
# 2  https://github.com/awslabs/aws-jwt-verify.git               src/jwt-rsa.ts
# 3  https://github.com/awslabs/aws-jwt-verify.git               src/jwt-rsa.ts
# 4  https://github.com/awslabs/aws-jwt-verify.git               src/jwt-rsa.ts
#
#                                      commit  \
# 0  5c706a33a9f44f4cde06c7b624c03353afa39938
# 1  eb64c77e7d0f77f9b36eecb0f7f078797337b729
# 2  80636886e4d9019dadc7ac7a94c174e06a31f913
# 3  80636886e4d9019dadc7ac7a94c174e06a31f913
# 4  80636886e4d9019dadc7ac7a94c174e06a31f913
#
#                                           commit_msg  \
# 0             Add more documentation, fix a few bugs
# 1  Re-introduce validate() and check for invalid ...
# 2  Include RS512 support for JWT signing algorith...
# 3  Include RS512 support for JWT signing algorith...
# 4  Include RS512 support for JWT signing algorith...
#
#                              id   kind
# 0        ngrx/example-app.git#0  jsdoc
# 1           spruceid/siwe.git#1  jsdoc
# 2  awslabs/aws-jwt-verify.git#0  jsdoc
# 3  awslabs/aws-jwt-verify.git#1  jsdoc
# 4  awslabs/aws-jwt-verify.git#2  jsdoc
#
# [5 rows x 23 columns]

# %%
comments_df['commit_url'] = comments_df.apply(lambda row: f'{row.repo_url[:-4]}/commit/{row.commit[:12]}', axis=1)

# %%
comment_pattern = 'javadoc|jsdoc|docstr|godoc|tsdoc|documenta|comment'
comment_update_verbs = ['fix', 'update', 'address', 'revise', 'modify', 'amend', 'outdate', 'change']
comment_update_verbs = ['fix']

# Filter dataset to only entries where commit_msg contains comment_pattern and one of the comment_update_verbs
comments_df = comments_df[comments_df['commit_msg'].str.contains(comment_pattern, case=False)]
comments_df = comments_df[comments_df['commit_msg'].str.contains('|'.join(comment_update_verbs), case=False)]
# Filter out qualified_name == constructor
comments_df = comments_df[comments_df['qualified_name'] != 'constructor']

# Print size
print('Total comments after filtering: {}'.format(len(comments_df)))
# Out:
# Total comments after filtering: 295

# %%
# Set column max to 200
pd.set_option('display.max_colwidth', 200)
# Order by length of commit_msg and print first 10, take only 1 from each repo_url
# take a random sample of size TOP_N
top_df = comments_df.sort_values(by='commit_msg', key=lambda col: col.str.len()).groupby('repo_url').head(1).sample(TOP_N)
# top_df = comments_df.sort_values(by='commit_msg', key=lambda col: col.str.len()).groupby('repo_url').head(1).head(TOP_N)
top_df
# Out:
#                                                                                                                                                                                        old_entire_comment_raw  \
# 3288                                                                   /**\n * Returns the service endpoints that exist in provider.\n * @param {any} endpoints\n * @return {Promise<ServiceEndpoint[]>}\n */
# 3767                                    /**\n * Override this in a derived class to provide logic for when a team is deleted.\n * @param handler\n * @returns A promise that represents the work queued.\n */
# 1083  /**\n * Optionally configure various options, such as response parsing, that the SDK allows.\n *\n * @param config Object of supported SDK options and toggles.\n * @param config.parseResponse If r...
# 140   /**\n * Randomly samples from the distribution represented by the bayesian network,\n * making sure the sample is consistent with the provided restrictions on value possibilities.\n * Returns fals...
# 3185  /**\n * Get image tiles urls for a single tile or\n * a tile level.\n *\n * @param {ImageTilesRequestContract} tiles - Tiles to request\n * @returns {Promise<ImageTilesContract>} Promise to the\n ...
# 3339                                                                                            /**\n * Returns a translated string from a key and a locale\n * @param {string} key\n * @return {string}\n */
# 2648  /**\n * Returns url for a `new` action in given Resource. Uses {@link resourceActionUrl}\n *\n * @param {string} resourceId  id to the resource\n * @param {string} [search]        optional query s...
# 1930                                                                                                                                                        // NOTE: positions of achievements are 1-indexed.
# 0                                  /**\n * This method creates an observable that waits for the `loaded` property\n * of the collection to turn `true`, emitting one time once loading\n * has finished.\n */
# 853   // For positive fragments (Has/HasValue) we need to find any passing entity up the proxy chain\n// so as soon as passes is true, we can early return. For negative fragments (Not/NotValue) every en...
# 3076                                                                                                                                                                                     /** Apply physics */
# 497                                                                                                          /**\n * Downloads the binary blob from the blob path\n * @param asset The asset to download\n */
# 475                                                             /**\n * Broadcast the transaction using the "async" mode, returning after CheckTx() is performed.\n * @param tx transaction to broadcast\n */
# 3126                                                           /**\n * Create an input rule that listens converts the code fence into a code block\n * when typing triple back tick followed by a space.\n */
# 344                                                                                                                                     /**\n * Register jQuery AjaxSetup to add the X-Socket-ID header.\n */
# 1040                                        /**\n * Invokes the zipalign tool from the Android SDK\n * @param {string} input path to the input file.\n * @param {string} output path to the output file.\n */
# 1254  /**\n * Get Owned NFTs\n *\n * @remarks Get all the data associated with the NFTs owned by a specific wallet.\n *\n * @example\n * ```javascript\n * // Address of the wallet to get the NFTs of\n *...
# 134                                                                                                                                      /**\n * Adds a new code lens at the given location in the file.\n */
# 2871  /**\n * Set camera's target\n * @public\n * @param target Target in world space\n * @example\n * ```js\n * // store position, target\n * const position = viewer.getCameraPosition();\n * const targ...
# 3312  /**\n * Checks if the given url respons in the given timeout\n * and returns a result object corresponding to the result\n * @param key The key which will be used for the result object\n *\n * @th...
# 115                                                                                                                                     /**\n * Get metadata about a single vault\n *\n * @param vaultId\n */
# 3821                                                                                                                                                                                     /**\n * METHODS\n */
# 1647                                    /**\n * Retrieves all counters. Will take pagination into account.\n *\n * @param detailed If true will request additional counter values from the REST endpoint\n */
# 2731  /**\n * Opens the Metamask extension page in the current window. It'll automatically\n * lookup the extension ID from the Extensions Inspector and save the `home`\n * and `popup` URLs for later us...
# 2218                                                                                                                                                 /**\n * Dispose of the resources held by the model.\n */
# 1444                                                       /**\n * If true, then the TSDocConfigFile object contains an empty state, because the `tsdoc.json` file could\n * not be found by the loader.\n */
# 554   /**\n * If the page page does not come from local file,\n * then we create this api to track the source of page data.\n * When a file is unlinked,\n * the data associated with it will automaticall...
# 795   /**\n * Gets the curent read endpoint for a geo-replicated database account.\n * @memberof DocumentClient\n * @instance\n * @param {function} callback        - The callback function which takes en...
# 2510  /**\n * Create a mosaic supply change transaction object\n * @param deadline - The deadline to include the transaction.\n * @param actionType - The namespace id.\n * @param namespaceId - The names...
# 1390                                              // Deserializing needs to be async because templates (e.g. few_shot) can\n// reference remote resources that we read asynchronously with a web\n// request.
# 2055  /**\n * Verify a signature of a given hash\n * @warning This method is not recommended, use verifyMessage instead\n *\n * @param hash - hash to be verified\n * @param signature - signature of the ...
# 361                                                                                                                             /**\n * Creates Model given input claims.\n * @param claims Input claims\n */
# 1590                                                                        /**\n * Signs a hash using the current owner account.\n *\n * @param hash - The hash to sign\n * @returns The Safe signature\n */
# 3917                                                                        /**\n * Find closest parent node of {@param node} by {@param predicate}.\n * Optional {@param skipSelf} to skip initial node\n */
# 3384                                                                                                                                      /**\n * Creates a {@link Page} in the default browser context.\n */
# 2117  /**\n * Send video files, Telegram clients support mp4 videos (other formats may be sent as Document)\n * Bots can currently send video files of up to 50 MB in size, this limit may be changed in t...
# 2169                                                                           /**\n * Convenience method\n *\n * const name = await identifier.getLatestClaimValue({type: 'name'})\n *\n * @param where\n */
# 1170  /**\n * Preloads the Magic `<iframe>` context, allowing for faster initial\n * requests. Awaiting the returned promise will signal when the `<iframe>` has\n * completed loading and is ready for re...
# 3402  // Note that onBeforeShutdown() and onBeforeWindowClose() are fired in different order depending on the OS:\n// - macOS: since the app will not quit when closing the last window, you will always f...
# 681                                                                                                                                                       /** Get all VerificationAdd* messages for an fid */
# 2164                                                                                                                                              /**\n * Gets the minimum zoom value\n * @returns {any}\n */
# 3596                                                                                                               /**\n * Resets the navigation stack and navigate to the root page and make it visible\n */
# 1513  /**\n * Creates a new {@link appCheck.AppCheckToken `AppCheckToken`} that can be sent\n * back to a client.\n *\n * @param appId The app ID to use as the JWT app_id.\n * @param options Optional op...
# 2634                                 /**\n * Obtains the latest element (LIFO) without removing it. Throws an exception if a buffer is\n * empty. Before calling this method, make sure that `size > 0`.\n */
# 2160                                                         // Compile an expression, evaluate it, convert to TlaEx, then to a string,\n// compare the result. This is the easiest path to test the results.
# 1414  /**\n * Checks whether there are any pending approvals associated with the given\n * origin.\n *\n * @param origin - The origin to check.\n * @returns True if the origin has no pending approvals, ...
# 1588                                                                                                                                           /** Check if every value/key in Collection satisfy callback */
# 539   /**\n * Gets the list of all the active properties from the provided linked twins\n * Returns them with the Alias as a prefix. ex: LinkedTwin.MyProperty\n * @param twins List of twins the get the ...
# 256                        /**\n * Constructs an exact out trade with the given amount out and route\n * @param route route of the exact out trade\n * @param amountOut the amount returned by the trade\n */
# 1089                                                                                                                 /**\n * Enables verbose debug logging\n * @returns {ApplicationInsights} this class\n */
#
#                                                                                                                                                                                        new_entire_comment_raw  \
# 3288  /**\n * This function returns an array of service endpoints for a given provider endpoint.\n * @param {string} providerEndpoint - The provider endpoint\n * @param {any} endpoints - The endpoints o...
# 3767                             /**\n * Registers a handler for TeamsTeamDeleted events, such as for when a team is deleted.\n * @param handler\n * @returns A promise that represents the work queued.\n */
# 1083                                                                /**\n * Optionally configure various options that the SDK allows.\n *\n * @param config Object of supported SDK options and toggles.\n */
# 140   /**\n * Randomly samples values from the distribution represented by the bayesian network,\n * making sure the sample is consistent with the provided restrictions on value possibilities.\n * Retur...
# 3185  /**\n * Get image tiles urls for a tile level.\n *\n * @param {ImageTilesRequestContract} tiles - Tiles to request\n * @returns {Promise<ImageTilesContract>} Promise to the\n * image tiles respons...
# 3339                                               /**\n * Returns a translated string from a key in the current {@link Language.locale}\n * @param key - Translation key\n * @returns Translated string\n */
# 2648  /**\n * Returns url for a `list` action in given Resource. Uses {@link resourceActionUrl}\n *\n * @param {string} resourceId  id to the resource\n * @param {string} [search]        optional query ...
# 1930        /**\n * Changes the position of the achievement\n *\n * Note: positions of achievements are 1-indexed\n *\n * @param achievement the AchievementItem\n * @param newPosition the new position\n */
# 0                            /**\n * This method creates an observable that waits for the `loaded` property\n * of the collection state to turn `true`, emitting one time once loading\n * has finished.\n */
# 853   /**\n * Helper function to check whether the result of a query pass check is a breaking state.\n *\n * @remarks\n * For positive fragments (Has/HasValue) we need to find any passing entity up the ...
# 3076                                                                                                                                                                      /** Apply physics and collisions */
# 497                                                                                                         /**\n * Downloads the binary blob from the asset path\n * @param asset The asset to download\n */
# 475                                                       /**\n * Broadcast the transaction using the "async" mode, returns immediately (transaction might fail).\n * @param tx transaction to broadcast\n */
# 3126  /**\n * Create an input rule that listens for input of 3 colons followed\n * by a valid callout type, to create a callout node\n * If the callout type is invalid, the defaultType callout is create...
# 344                                                                                                                                 /**\n * Register jQuery AjaxPrefilter to add the X-Socket-ID header.\n */
# 1040  /**\n * Invokes the zipalign tool from the Android SDK with the following flags:\n *  -f   : overwrite existing outfile.zip.\n *  -v   : verbose output.\n *  -p 4 : align all libraries to the 32-b...
# 1254  /**\n * Get all NFTs owned by a specific wallet\n *\n * @remarks Get all the data associated with the NFTs owned by a specific wallet.\n *\n * @example\n * ```javascript\n * // Address of the wall...
# 134                                                                                                                                      /**\n * Adds a new code lens at the given treeNode in the file.\n */
# 2871  /**\n * Set camera's target.\n * @public\n * @param target Target in world space.\n * @example\n * ```js\n * // store position, target\n * const position = viewer.getCameraPosition();\n * const ta...
# 3312  /**\n * Checks if the size of the given size has exceeded the\n * given threshold\n *\n * @param key The key which will be used for the result object\n *\n * @throws {HealthCheckError} In case the...
# 115                                                                                                      /**\n * Get metadata about a single vault with the provided ID.\n *\n * @param {string} vaultId\n */
# 3821                                                                                                                                                     // Triggers refetch of all queries in this provider.
# 1647                                                                                    /**\n * Retrieves a single counter.\n *\n * @param counterName Name of the counter for which to retrieve details\n */
# 2731  /**\n * Only used if the `--discover-metamask` flag is passed to the test runner.\n *\n * Opens the Metamask extension page in the current window. It'll automatically\n * lookup the extension ID f...
# 2218                                                                                                                                                                 /**\n * Dispose of model resources.\n */
# 1444  /**\n * If true, then the TSDocConfigFile object contains an empty state, because the `tsdoc.json` file\n * was not found by the loader.\n *\n * @remarks\n * A missing "tsdoc.json" file is not con...
# 554   /**\n * If the page comes from local file,\n * then we create this api to track the source of page data.\n * When a file is unlinked,\n * the data associated with it will automatically get deleted...
# 795                                                                                                                                                                                     // NOT USED IN NEW OM
# 2510  /**\n * Create a address alias transaction object\n * @param deadline - The deadline to include the transaction.\n * @param actionType - The alias action type.\n * @param namespaceId - The namespa...
# 1390  /**\n * Load a prompt template from a json-like object describing it.\n *\n * @remarks\n * Deserializing needs to be async because templates (e.g. {@link FewShotPromptTemplate}) can\n * reference ...
# 2055  /**\n * Verify a signature of a JSON object\n *\n * @param hash - hash to be verified\n * @param signature - signature of the hash\n * @returns true if the signature is valid, false otherwise\n * ...
# 361                                                                                                                    /**\n * Creates an InputClaimInstance for a contract using a subset of properties\n */
# 1590                                                                       /**\n * Signs a hash using the current signer account.\n *\n * @param hash - The hash to sign\n * @returns The Safe signature\n */
# 3917                                                                                             /**\n * Find closest parent node of `node` by `predicate`.\n * Optional `skipSelf` to skip initial node\n */
# 3384                                                                                  /**\n * Promise which resolves to a new {@link Page} object. The Page is created in\n * a default browser context.\n */
# 2117  /**\n * Send video files, Telegram clients support mp4 videos (other formats may be sent as Document).\n * Bots can currently send video files of up to 50 MB in size, this limit may be changed in ...
# 2169  /**\n * Convenience method to get the most recent information about a subject DID as described by Verifiable Credential\n * claims.\n *\n * Example:\n * ```typescript\n * // get the latest claim v...
# 1170  /**\n * Preloads the Magic view, allowing for faster initial requests in browser\n * environments. Awaiting the returned promise will signal when the Magic view\n * has completed loading and is re...
# 3402  // Note that onBeforeShutdown() and onBeforeCloseWindow() are fired in different order depending on the OS:\n// - macOS: since the app will not quit when closing the last window, you will always f...
# 681   /**\n * Finds all VerificationAdds messages for a user\n *\n * @param fid fid of the user who created the signers\n * @returns the VerificationAddEthAddresses if they exists, throws NotFoundError ...
# 2164                                                                                                                                    /**\n * Gets the minimum zoom value in meters\n * @returns {any}\n */
# 3596                                                                                                          /**\n * Resets the navigation stack by navigating back to the root page and displaying it.\n */
# 1513  /**\n * Creates a new {@link AppCheckToken} that can be sent\n * back to a client.\n *\n * @param appId - The app ID to use as the JWT app_id.\n * @param options - Optional options object when cre...
# 2634                                 /**\n * Obtains the oldest element (FIFO) without removing it. Throws an exception if a buffer is\n * empty. Before calling this method, make sure that `size > 0`.\n */
# 2160                                                         // Compile an expression, evaluate it, convert to TntEx, then to a string,\n// compare the result. This is the easiest path to test the results.
# 1414  /**\n * Checks whether there are any approvals associated with the given\n * origin.\n *\n * @param origin - The origin to check.\n * @returns True if the origin has no approvals, false otherwise....
# 1588                                                                                                                                         /** Check if every value/key in Collection satisfies callback */
# 539   /**\n * Gets the list of all (union of) the active properties from the provided linked twins\n * Returns them with the Alias as a prefix. ex: LinkedTwin.MyProperty\n * @param twins List of twins t...
# 256   /**\n * Constructs an exact out trade with the given amount out and route\n * @template TInput The input token, either Ether or an ERC-20\n * @template TOutput The output token, either Ether or an...
# 1089                                  /**\n * Enables debug and warning logging for AppInsights itself.\n * @param enableWarningLogging also show warnings\n * @returns {ApplicationInsights} this class\n */
#
#                                                                                                                                                                                                  old_code_raw  \
# 3288  public async getServiceEndpoints(providerEndpoint: string, endpoints: any) {\n  const serviceEndpoints: ServiceEndpoint[] = []\n  for (const i in endpoints.serviceEndpoints) {\n    const endpoint:...
# 3767  public onTeamsTeamDeletedEvent(\n    handler: (teamInfo: TeamInfo, context: TurnContext, next: () => Promise<void>) => Promise<void>\n): this {\n    return this.on('TeamsTeamDeleted', async (conte...
# 1083                                                                                                                                       config(config: ConfigOptions) {\n  this.core.setConfig(config);\n}
# 140                      generateConsistentSampleWhenPossible(valuePossibilities: Record<string, string[]>) {\n    return this.recursivelyGenerateConsistentSampleWhenPossible({}, valuePossibilities, 0);\n}
# 3185                                        public getImageTiles(\n    tiles: ImageTilesRequestContract): Promise<ImageTilesContract> {\n    return Promise.reject(new MapillaryError("Not implemented"));\n}
# 3339                   get(key: string): string {\n    const translation = getTranslation(this.translations, key);\n    if (translation !== null) {\n        return translation;\n    }\n\n    return key;\n}
# 2648                                                                   listUrl(resourceId: string, search?: string): string {\n  return this.resourceActionUrl({ resourceId, actionName: 'list', search })\n}
# 1930  public changeAchievementPosition(achievement: AchievementItem, newPosition: number) {\n  const achievements = this.getAchievements()\n    .filter(achievement => achievement.isTask)\n    .sort((tas...
# 0                                                                                waitForCollectionToLoad() {\n  return this.store.let(getCollectionLoaded())\n    .filter(loaded => loaded)\n    .take(1);\n}
# 853                function isBreakingPassState(passes: boolean, fragment: EntityQueryFragment<Schema>) {\n  return (passes && isPositiveFragment(fragment)) || (!passes && isNegativeFragment(fragment));\n}
# 3076                                                                                                                                                                                     move(dt: number) { }
# 497   public static async getAssetBlob(asset: IAsset): Promise<Blob> {\n    Guard.null(asset);\n\n    const config: AxiosRequestConfig = {\n        responseType: "blob",\n    };\n\n    // Download the a...
# 475   public async broadcastAsync(tx: Tx): Promise<AsyncTxBroadcastResult> {\n  return this._broadcast<{ tx_response: AsyncTxBroadcastResult.Data }>(\n    tx,\n    'BROADCAST_MODE_ASYNC'\n  ).then(({ tx...
# 3126  createInputRules(): InputRule[] {\n  return [\n    nodeInputRule({\n      regexp: /^:::([\dA-Za-z]*) $/,\n      type: this.type,\n      beforeDispatch: ({ tr, start }) => {\n        const $pos = t...
# 344   registerjQueryAjaxSetup(): void {\n    if (typeof jQuery.ajax != 'undefined') {\n        jQuery.ajaxPrefilter((options, originalOptions, xhr) => {\n            if (this.socketId()) {\n            ...
# 1040  async zipalign(input: string, output: string): Promise<void> {\n  const env = this.getEnv();\n  const zipalignCmd = [\n    `"${this.pathJoin(this.getAndroidHome(), `/build-tools/${BUILD_TOOLS_VERS...
# 1254  public async all(walletAddress?: string): Promise<NFT[]> {\n  const tokenIds = await this.tokenIds(walletAddress);\n  return await Promise.all(\n    tokenIds.map((tokenId) => this.erc721.get(token...
# 134   protected set(file: string, position: Position, data: ITreeNode) {\n  let list = this.data.get(lowerCaseInsensitivePath(file));\n  if (!list) {\n    list = [];\n    this.data.set(lowerCaseInsensit...
# 2871                                               setCameraTarget(target: THREE.Vector3): void {\n  if (this.isDisposed) {\n    return;\n  }\n  this.controls.setState(this.getCameraPosition(), target);\n}
# 3312                                            async check(\n  key: string,\n  options: DiskHealthIndicatorOptions,\n): Promise<HealthIndicatorResult> {\n  return await this.checkStorage(key, options);\n}
# 115   public async getVaultById(vaultId: string): Promise<Vault> {\n    const { data } = await this.adapter.sendRequest(\n        "get",\n        `${this.basePath}/${vaultId}`,\n    );\n    return Objec...
# 3821  async function refetchAllPoolStakingData() {\n  return Promise.all([\n    refetchPoolGauges.value(),\n    refetchStakedShares.value(),\n    refetchUserGaugeShares.value(),\n    refetchUserBoosts.v...
# 1647  private getSingleCounter(counterName: string): Observable<Counter> {\n    const requestOptionsArgs: RequestOptionsArgs = HttpUtils.getDefaultRequestOptions();\n    return this.http.get(this.metric...
# 2731  async openMetamask() {\n  if (!process.argv.includes("--discover-metamask")) {\n    await this.switchToMetamask();\n    return;\n  }\n\n  if (this.homeUrl && this.popupUrl) {\n    await this.navig...
# 2218                                                         dispose(): void {\n  if (this.isDisposed) {\n    return;\n  }\n  this._isDisposed = true;\n  this._poll.dispose();\n  Signal.clearData(this);\n}
# 1444                                                                                                                                    public get fileNotFound(): boolean {\n  return this._fileNotFound;\n}
# 554   createAPIForSourceFile(\n  sourceFile: File,\n  scheduleUpdate: ScheduleUpdate\n): HandlerAPI {\n  const getRuntimeData: HandlerAPI['getRuntimeData'] = (pageId) =>\n    this.createMutableProxy(pag...
# 795   public getReadEndpoint(callback?: (readEndPoint: string) => void): void | Promise<string> {\n    const p = this._globalEndpointManager.getReadEndpoint();\n\n    if (callback) {\n        p.then(cal...
# 2510  public static create(deadline: Deadline,\n                     actionType: AliasActionType,\n                     namespaceId: NamespaceId,\n                     address: Address,\n               ...
# 1390  static async deserialize(\n  data: SerializedBasePromptTemplate\n): Promise<BasePromptTemplate> {\n  switch (data._type) {\n    case "prompt":\n      return PromptTemplate.deserialize(data);\n    ...
# 2055      public async verifyMessage(typedData: TypedData, signature: Signature): Promise<boolean> {\n  const hash = await this.hashMessage(typedData);\n  return this.verifyMessageHash(hash, signature);\n}
# 361                                                                                                     forInput(): InputClaimModel {\n  return new InputClaimModel(this.claim, this.type, this.required);\n}
# 1590  async signTransactionHash(hash: string): Promise<SafeSignature> {\n  if (!this.#signer) {\n    throw new Error('No signer provided')\n  }\n  const owners = await this.getOwners()\n  if (\n    !own...
# 3917  static closestBy(node: Node | null, predicate: (node: Node) => boolean, skipSelf = false): Node | null {\n  let current = skipSelf && node ? node.parentNode : node;\n  while (current) {\n    if (p...
# 3384                                                                                                                            async newPage(): Promise<Page> {\n  return this._defaultContext.newPage();\n}
# 2117               sendVideo(\n  chatId: number | string,\n  video: tg.Opts<'sendVideo'>['video'],\n  extra?: tt.ExtraVideo\n) {\n  return this.callApi('sendVideo', { chat_id: chatId, video, ...extra })\n}
# 2169  async getLatestClaimValue(\n  dbConnection: Promise<Connection>,\n  where: any,\n): Promise<string | null | undefined> {\n  const claim = await (await dbConnection).getRepository(Claim).findOne({\...
# 1170                                                                                                                                                 public async preload() {\n  await this.overlay.ready;\n}
# 3402                                                                                             private onBeforeShutdown(): void {\n        this.shuttingDown = true;\n\n        this.saveWindowsState();\n}
# 681   async getVerificationAddsByUser(fid: Uint8Array): Promise<VerificationAddEthAddressModel[]> {\n  const addsPrefix = VerificationStore.verificationAddsKey(fid);\n  const messageKeys: Buffer[] = [];...
# 2164                                                                                              getMinimumZoom() : number {\n    return this.getScene().screenSpaceCameraController.minimumZoomDistance;\n}
# 3596                                                                                                                                       popToRootSettingsPanelPage(): void {\n  this.resetNavigation();\n}
# 1513  public createToken(appId: string, options?: AppCheckTokenOptions): Promise<AppCheckToken> {\n  return this.tokenGenerator.createCustomToken(appId, options)\n    .then((customToken) => {\n      ret...
# 2634                                                              get top(): T {\n    if (this.size === 0) {\n        throw new Error("Ringbuffer underrun");\n    }\n\n    return this.buffer[this.tail];\n}
# 2160  function assertResultAsString(input: string, expected: string | undefined) {\n  const moduleText = `module __runtime { val __expr = ${input} }`\n  const context = compile(moduleText).values\n  con...
# 1414                                                                                                         private _isEmptyOrigin(origin: string): boolean {\n  return !this._origins.get(origin)?.size;\n}
# 1588  every(callback: (value: V, key: K) => boolean): boolean {\n  for (const key of this.keys()) {\n    const value = this.get(key) as V\n    if (!callback(value, key)) return false\n  }\n  return true\n}
# 539   static getPropertyNamesWithAliasFromTwins(twins: Record<string, any>) {\n    const properties = new Set<string>();\n    for (const alias in twins) {\n        const twin = twins[alias];\n        co...
# 256   public static async exactOut<TInput extends Currency, TOutput extends Currency>(\n  route: Route<TInput, TOutput>,\n  amountOut: CurrencyAmount<TOutput>\n): Promise<Trade<TInput, TOutput, TradeTyp...
# 1089             public static enableVerboseLogging(enableWarningLogging = true) {\n    Logging.enableDebug = true;\n    Logging.disableWarnings = !enableWarningLogging;\n    return ApplicationInsights;\n}
#
#                                                                                                                                                                                                  new_code_raw  \
# 3288  public async getServiceEndpoints(providerEndpoint: string, endpoints: any) {\n  const serviceEndpoints: ServiceEndpoint[] = []\n  for (const i in endpoints.serviceEndpoints) {\n    const endpoint:...
# 3767  public onTeamsTeamDeletedEvent(\n    handler: (teamInfo: TeamInfo, context: TurnContext, next: () => Promise<void>) => Promise<void>\n): this {\n    return this.on('TeamsTeamDeleted', async (conte...
# 1083                                                                                                                                       config(config: ConfigOptions) {\n  this.core.setConfig(config);\n}
# 140                      generateConsistentSampleWhenPossible(valuePossibilities: Record<string, string[]>) {\n    return this.recursivelyGenerateConsistentSampleWhenPossible({}, valuePossibilities, 0);\n}
# 3185                                        public getImageTiles(\n    tiles: ImageTilesRequestContract): Promise<ImageTilesContract> {\n    return Promise.reject(new MapillaryError("Not implemented"));\n}
# 3339                   get(key: string): string {\n    const translation = getTranslation(this.translations, key);\n    if (translation !== null) {\n        return translation;\n    }\n\n    return key;\n}
# 2648                                                                   listUrl(resourceId: string, search?: string): string {\n  return this.resourceActionUrl({ resourceId, actionName: 'list', search })\n}
# 1930  public changeAchievementPosition(achievement: AchievementItem, newPosition: number) {\n  const achievements = this.getAchievements()\n    .filter(achievement => achievement.isTask)\n    .sort((tas...
# 0                                                                                waitForCollectionToLoad() {\n  return this.store.let(getCollectionLoaded())\n    .filter(loaded => loaded)\n    .take(1);\n}
# 853                function isBreakingPassState(passes: boolean, fragment: EntityQueryFragment<Schema>) {\n  return (passes && isPositiveFragment(fragment)) || (!passes && isNegativeFragment(fragment));\n}
# 3076                                                                                                                                                                                     move(dt: number) { }
# 497   public static async getAssetBlob(asset: IAsset): Promise<Blob> {\n    Guard.null(asset);\n\n    const config: AxiosRequestConfig = {\n        responseType: "blob",\n    };\n\n    // Download the a...
# 475   public async broadcastAsync(tx: Tx): Promise<AsyncTxBroadcastResult> {\n  return this._broadcast<{ tx_response: AsyncTxBroadcastResult.Data }>(\n    tx,\n    'BROADCAST_MODE_ASYNC'\n  ).then(({ tx...
# 3126  createInputRules(): InputRule[] {\n  return [\n    nodeInputRule({\n      regexp: /^:::([\dA-Za-z]*) $/,\n      type: this.type,\n      beforeDispatch: ({ tr, start }) => {\n        const $pos = t...
# 344   registerjQueryAjaxSetup(): void {\n    if (typeof jQuery.ajax != 'undefined') {\n        jQuery.ajaxPrefilter((options, originalOptions, xhr) => {\n            if (this.socketId()) {\n            ...
# 1040  async zipalign(input: string, output: string): Promise<void> {\n  const env = this.getEnv();\n  const zipalignCmd = [\n    `"${this.pathJoin(this.getAndroidHome(), `/build-tools/${BUILD_TOOLS_VERS...
# 1254  public async all(walletAddress?: string): Promise<NFT[]> {\n  const tokenIds = await this.tokenIds(walletAddress);\n  return await Promise.all(\n    tokenIds.map((tokenId) => this.erc721.get(token...
# 134   protected set(file: string, position: Position, data: ITreeNode) {\n  let list = this.data.get(lowerCaseInsensitivePath(file));\n  if (!list) {\n    list = [];\n    this.data.set(lowerCaseInsensit...
# 2871                                               setCameraTarget(target: THREE.Vector3): void {\n  if (this.isDisposed) {\n    return;\n  }\n  this.controls.setState(this.getCameraPosition(), target);\n}
# 3312                                            async check(\n  key: string,\n  options: DiskHealthIndicatorOptions,\n): Promise<HealthIndicatorResult> {\n  return await this.checkStorage(key, options);\n}
# 115   public async getVaultById(vaultId: string): Promise<Vault> {\n    const { data } = await this.adapter.sendRequest(\n        "get",\n        `${this.basePath}/${vaultId}`,\n    );\n    return Objec...
# 3821  async function refetchAllPoolStakingData() {\n  return Promise.all([\n    refetchPoolGauges.value(),\n    refetchStakedShares.value(),\n    refetchUserGaugeShares.value(),\n    refetchUserBoosts.v...
# 1647  private getSingleCounter(counterName: string): Observable<Counter> {\n        const requestOptionsArgs: RequestOptionsArgs = HttpUtils.getDefaultRequestOptions();\n        return this.http.get(thi...
# 2731  async openMetamask() {\n  if (!process.argv.includes("--discover-metamask")) {\n    await this.switchToMetamask();\n    return;\n  }\n\n  if (this.homeUrl && this.popupUrl) {\n    await this.navig...
# 2218                                                         dispose(): void {\n  if (this.isDisposed) {\n    return;\n  }\n  this._isDisposed = true;\n  this._poll.dispose();\n  Signal.clearData(this);\n}
# 1444                                                                                                                                    public get fileNotFound(): boolean {\n  return this._fileNotFound;\n}
# 554   createAPIForSourceFile(\n  sourceFile: File,\n  scheduleUpdate: ScheduleUpdate\n): HandlerAPI {\n  const getRuntimeData: HandlerAPI['getRuntimeData'] = (pageId) =>\n    this.createMutableProxy(pag...
# 795   public getReadEndpoint(callback?: (readEndPoint: string) => void): void | Promise<string> {\n    const p = this._globalEndpointManager.getReadEndpoint();\n\n    if (callback) {\n        p.then(cal...
# 2510  public static create(deadline: Deadline,\n                     actionType: AliasActionType,\n                     namespaceId: NamespaceId,\n                     address: Address,\n               ...
# 1390  static async deserialize(\n  data: SerializedBasePromptTemplate\n): Promise<BasePromptTemplate> {\n  switch (data._type) {\n    case "prompt":\n      return PromptTemplate.deserialize(data);\n    ...
# 2055      public async verifyMessage(typedData: TypedData, signature: Signature): Promise<boolean> {\n  const hash = await this.hashMessage(typedData);\n  return this.verifyMessageHash(hash, signature);\n}
# 361                                                                                                     forInput(): InputClaimModel {\n  return new InputClaimModel(this.claim, this.type, this.required);\n}
# 1590  async signTransactionHash(hash: string): Promise<SafeSignature> {\n  if (!this.#signer) {\n    throw new Error('No signer provided')\n  }\n  const owners = await this.getOwners()\n  if (\n    !own...
# 3917  static closestBy(node: Node | null, predicate: (node: Node) => boolean, skipSelf = false): Node | null {\n  let current = skipSelf && node ? node.parentNode : node;\n  while (current) {\n    if (p...
# 3384                                                                                                                            async newPage(): Promise<Page> {\n  return this._defaultContext.newPage();\n}
# 2117               sendVideo(\n  chatId: number | string,\n  video: tg.Opts<'sendVideo'>['video'],\n  extra?: tt.ExtraVideo\n) {\n  return this.callApi('sendVideo', { chat_id: chatId, video, ...extra })\n}
# 2169  async getLatestClaimValue(\n  dbConnection: Promise<Connection>,\n  where: any,\n): Promise<string | null | undefined> {\n  const claim = await (await dbConnection).getRepository(Claim).findOne({\...
# 1170                                                                                                                                                 public async preload() {\n  await this.overlay.ready;\n}
# 3402                                                                                             private onBeforeShutdown(): void {\n        this.shuttingDown = true;\n\n        this.saveWindowsState();\n}
# 681   async getVerificationAddsByUser(fid: Uint8Array): Promise<VerificationAddEthAddressModel[]> {\n  const addsPrefix = VerificationStore.verificationAddsKey(fid);\n  const messageKeys: Buffer[] = [];...
# 2164                                                                                              getMinimumZoom() : number {\n    return this.getScene().screenSpaceCameraController.minimumZoomDistance;\n}
# 3596                                                                                                                                       popToRootSettingsPanelPage(): void {\n  this.resetNavigation();\n}
# 1513  public createToken(appId: string, options?: AppCheckTokenOptions): Promise<AppCheckToken> {\n  return this.tokenGenerator.createCustomToken(appId, options)\n    .then((customToken) => {\n      ret...
# 2634                                                              get top(): T {\n    if (this.size === 0) {\n        throw new Error("Ringbuffer underrun");\n    }\n\n    return this.buffer[this.tail];\n}
# 2160  function assertResultAsString(input: string, expected: string | undefined) {\n  const moduleText = `module __runtime { val __expr = ${input} }`\n  const context = compile(moduleText).values\n  con...
# 1414                                                                                                         private _isEmptyOrigin(origin: string): boolean {\n  return !this._origins.get(origin)?.size;\n}
# 1588  every(callback: (value: V, key: K) => boolean): boolean {\n  for (const key of this.keys()) {\n    const value = this.get(key) as V\n    if (!callback(value, key)) return false\n  }\n  return true\n}
# 539   static getPropertyNamesWithAliasFromTwins(twins: Record<string, any>) {\n    const properties = new Set<string>();\n    for (const alias in twins) {\n        const twin = twins[alias];\n        co...
# 256   public static async exactOut<TInput extends Currency, TOutput extends Currency>(\n  route: Route<TInput, TOutput>,\n  amountOut: CurrencyAmount<TOutput>\n): Promise<Trade<TInput, TOutput, TradeTyp...
# 1089             public static enableVerboseLogging(enableWarningLogging = true) {\n    Logging.enableDebug = true;\n    Logging.disableWarnings = !enableWarningLogging;\n    return ApplicationInsights;\n}
#
#                                                                                                                                                                                               old_comment_raw  \
# 3288                                                                                                                                                    Returns the service endpoints that exist in provider.
# 3767                                                                                                                            Override this in a derived class to provide logic for when a team is deleted.
# 1083                                                                                                                     Optionally configure various options, such as response parsing, that the SDK allows.
# 140                                   Randomly samples from the distribution represented by the bayesian network, making sure the sample is consistent with the provided restrictions on value possibilities.
# 3185                                                                                                                                                  Get image tiles urls for a single tile or a tile level.
# 3339                                                                                                                                                      Returns a translated string from a key and a locale
# 2648                                                                                                                                                        Returns url for a `new` action in given Resource.
# 1930                                                                                                                                                           NOTE: positions of achievements are 1-indexed.
# 0                                                       This method creates an observable that waits for the `loaded` property of the collection to turn `true`, emitting one time once loading has finished.
# 853                                                            For positive fragments (Has/HasValue) we need to find any passing entity up the proxy chain so as soon as passes is true, we can early return.
# 3076                                                                                                                                                                                            Apply physics
# 497                                                                                                                                                              Downloads the binary blob from the blob path
# 475                                                                                                                 Broadcast the transaction using the "async" mode, returning after CheckTx() is performed.
# 3126                                                                            Create an input rule that listens converts the code fence into a code block when typing triple back tick followed by a space.
# 344                                                                                                                                                  Register jQuery AjaxSetup to add the X-Socket-ID header.
# 1040                                                                                                                                                           Invokes the zipalign tool from the Android SDK
# 1254                                                                                                                                                                                           Get Owned NFTs
# 134                                                                                                                                                   Adds a new code lens at the given location in the file.
# 2871                                                                                                                                                                              Set camera's target @public
# 3312                                                                                             Checks if the given url respons in the given timeout and returns a result object corresponding to the result
# 115                                                                                                                                                                         Get metadata about a single vault
# 3821                                                                                                                                                                                                  METHODS
# 1647                                                                                                                                                                                  Retrieves all counters.
# 2731                                                                                                                                                 Opens the Metamask extension page in the current window.
# ...
# 1647  gh-432 Port field-value-counter D3js widgets to Angular4 infrastructure\n\n* Migrate Pie chart component to Angular 4 and D3v4\n  - Add ability to define # of pie slices\n  - Add boolean flag weth...
# 2731                [greenboard] Adds documentation for using the package and creating new scenarios (#2101)\n\n* added prepare(), fixed bad docs\r\n\r\n* using prepare()\r\n\r\n* added docs for Greenboard
# 2218  Merge PR #630 "Provide UI feedback during Git command execution"\n\ncommit 1c2cb43d453d50f2dcf3cb3b55e752f60516de3c\nAuthor: Frederic Collonval <fcollonval@gmail.com>\nDate:   Fri Jul 24 18:24:42 ...
# 1444                                                                                                            Fix some issues with the logic for TSDocConfigFile.hasErrors and TSDocConfigFile.fileNotFound
# 554                                                                                                                                                                                        chore: fix comment
# 795   Feature/object model refactor (#26)\n\n* Move foreach to async iterator\r\n\r\n* Mock out new APIs\r\n\r\n* remove legacy tests\r\n\r\n* remove old ntvs stuff for samples\r\n\r\n* Add shimmed impl...
# 2510                                                                                                                          Fixed #117, Typo in AddressAliasTransaction and MosaicAliasTransaction comments
# 1390  fix: add initial documentation with typedoc (#16)\n\n* fix: add initial documentation with typedoc\r\n\r\n* feat: add docusaurus (#17)\r\n\r\n* feat: add docusaurus\r\n\r\n* fix: update docs\r\n\r...
# 2055                                                                                                                                                                 fix(account): function documentation fix
# 361                                                                                                                            fix comments (#82)\n\nCo-authored-by: Guillermo Proano <gproano@microsoft.com>
# 1590                                                                                                                                                                                        Fix documentation
# 3917                                                                                                                                                               docs(esl-utils): fix documentation linting
# 3384                                                                                                                                   fix: modified comment for method product, platform and newPage (#7262)
# 2117                                                                                                                       chore: minor tsdoc fixes\n\nSigned-off-by: Muthu Kumar <muthukumar@thefeathers.in>
# 2169  fix: update and fix inline documentation of all exported types (#921)\n\n* fix(build): use correct cross-package imports\r\n\r\n* chore(build): split build scripts for better granularity\r\n\r\n* ...
# 1170  Extensions (#72)\n\n* Add GZIP compression to query parameters\r\n\r\n* Add doc comment\r\n\r\n* Add strong typing for extensions\r\n\r\n* Expand extension typing to support dictionary as well\r\n...
# 3402  Squashed 'lib/vscode/' changes from 622cb03f7e0..fd6f3bce670\n\nfd6f3bce670 chore: bump electron@11.3.0 (#118680)\n305bf142199 Remove icon from input row in ports view (#118649)\nb5af426d34c Prope...
# 681   fix(VerificationStore): increase test coverage, change conflict resolution, add docs (#216)\n\n* docs: update verificationStore method docs\r\n\r\n* test: add coverage for merge methods\r\n\r\n* d...
# 2164                                                                                                        - Fixed comments\n- Merged the viewer factory methods by setting options parameter to be optional
# 3596                                                                                                                                                                   improve and fix typos in documentation
# 1513  chore: Enabled tsdoc error checking (#1459)\n\n* chore: Enabled tsdoc error checking\r\n\r\n* fix: Fixing a lint error\r\n\r\n* fix: Minor internal doc comment updates\r\n\r\n* fix: Updating doc c...
# 2634  HARP-4531: Fix getLastFrameStatistics to return latest frame value\n\n  RingBuffer implementation is actually FIFO, comments updated.\n  Added "bottom" method for retrieving latest element, expand...
# 2160  Mode checker fix for polymorphic operators (#447)\n\n* Use same mode checker strat for all effects\r\n\r\n* Fix bug in effect substitutions\r\n\r\n* Fix minor issues on documentation\r\n\r\n* Upda...
# 1414  Add default type and timestamps to approval controller (#309)\n\n* Add approval controller request times\r\n\r\n* Fix ApprovalInfo interface documentation\r\n\r\n* Fix some docstrings\r\n\r\n* Rem...
# 1588                                                           miner grammer/typo fixes is comments. Changed all comments I can find to consider method as a singular noun, tho I might missed a few comments
# 539   feat: Twin alias in behavior (#316)\n\n* initial twin alias tab implementation for behavior\r\n\r\n* callout ui added for adding from existing twin aliases\r\n\r\n* linting fixes\r\n\r\n* elements...
# 256   Comment Updates (#45)\n\n* updates various sdk comments`\r\n\r\n* cleanup\r\n\r\n* Fix code style issues with Prettier\r\n\r\n* update re comments\r\n\r\n* Fix code style issues with Prettier\r\n\...
# 1089                                                                                              edits to comments in applicationinsights.ts (#223)\n\n* edits to comments\r\n\r\n* fixup! edits to comments
#
#                                                                       id  \
# 3288                                       oceanprotocol/ocean.js.git#67
# 3767                                     microsoft/botbuilder-js.git#315
# 1083                                                  readmeio/api.git#0
# 140                                        apify/fingerprint-suite.git#0
# 3185                                       mapillary/mapillary-js.git#90
# 3339                                               Adyen/adyen-web.git#2
# 2648                                     SoftwareBrothers/adminjs.git#14
# 1930                                       source-academy/frontend.git#2
# 0                                                 ngrx/example-app.git#0
# 853                                                 latticexyz/mud.git#0
# 3076                               microsoft/pxt-common-packages.git#400
# 497                                                 microsoft/VoTT.git#0
# 475                                           terra-money/terra.js.git#5
# 3126                                            remirror/remirror.git#28
# 344                                                  laravel/echo.git#11
# 1040                                   GoogleChromeLabs/bubblewrap.git#0
# 1254                                              thirdweb-dev/js.git#79
# 134                         microsoft/vscode-js-profile-visualizer.git#0
# 2871                                            cognitedata/reveal.git#7
# 3312                                               nestjs/terminus.git#2
# 115                                       1Password/connect-sdk-js.git#3
# 3821                                          balancer/frontend-v2.git#2
# 1647                         spring-cloud/spring-cloud-dataflow-ui.git#1
# 2731                                      counterfactual/monorepo.git#16
# 2218                                    jupyterlab/jupyterlab-git.git#17
# 1444                                              microsoft/tsdoc.git#52
# 554                                 vitejs/vite-plugin-react-pages.git#0
# 795                                          Azure/azure-cosmos-js.git#1
# 2510                      symbol/symbol-sdk-typescript-javascript.git#10
# 1390                                         hwchase17/langchainjs.git#0
# 2055                                            0xs34n/starknet.js.git#4
# 361   microsoft/VerifiableCredentials-Verification-SDK-Typescript.git#10
# 1590                                     safe-global/safe-core-sdk.git#1
# 3917                                               exadel-inc/esl.git#57
# 3384                                           puppeteer/puppeteer.git#7
# 2117                                             telegraf/telegraf.git#3
# 2169                                          uport-project/veramo.git#1
# 1170                                            magiclabs/magic-js.git#7
# 3402                                             coder/code-server.git#6
# 681                                     farcasterxyz/hub-monorepo.git#14
# 2164                                    articodeltd/angular-cesium.git#0
# 3596                                  bitmovin/bitmovin-player-ui.git#17
# 1513                                 firebase/firebase-admin-node.git#51
# 2634                                              heremaps/harp.gl.git#5
# 2160                                         informalsystems/quint.git#4
# 1414                                                 MetaMask/core.git#2
# 1588                                          harmonyland/harmony.git#53
# 539                                     microsoft/iot-cardboard-js.git#0
# 256                                                Uniswap/v3-sdk.git#10
# 1089                         microsoft/ApplicationInsights-node.js.git#4
#
#        kind  \
# 3288  jsdoc
# 3767  jsdoc
# 1083  jsdoc
# 140   jsdoc
# 3185  jsdoc
# 3339  jsdoc
# 2648  jsdoc
# 1930     md
# 0     jsdoc
# 853      fd
# 3076  jsdoc
# 497   jsdoc
# 475   jsdoc
# 3126  jsdoc
# 344   jsdoc
# 1040  jsdoc
# 1254  jsdoc
# 134   jsdoc
# 2871  jsdoc
# 3312  jsdoc
# 115   jsdoc
# 3821  jsdoc
# 1647  jsdoc
# 2731  jsdoc
# 2218  jsdoc
# 1444  jsdoc
# 554   jsdoc
# 795   jsdoc
# 2510  jsdoc
# 1390     md
# 2055  jsdoc
# 361   jsdoc
# 1590  jsdoc
# 3917  jsdoc
# 3384  jsdoc
# 2117  jsdoc
# 2169  jsdoc
# 1170  jsdoc
# 3402     md
# 681   jsdoc
# 2164  jsdoc
# 3596  jsdoc
# 1513  jsdoc
# 2634  jsdoc
# 2160     fd
# 1414  jsdoc
# 1588  jsdoc
# 539   jsdoc
# 256   jsdoc
# 1089  jsdoc
#
#                                                                                               commit_url
# 3288                                       https://github.com/oceanprotocol/ocean.js/commit/9bf71ba4f078
# 3767                                      https://github.com/microsoft/botbuilder-js/commit/6e1009b256f3
# 1083                                                 https://github.com/readmeio/api/commit/18ddbfb223b5
# 140                                       https://github.com/apify/fingerprint-suite/commit/9d32a69b3eca
# 3185                                       https://github.com/mapillary/mapillary-js/commit/99f65410ee95
# 3339                                              https://github.com/Adyen/adyen-web/commit/d5828f2d98c6
# 2648                                     https://github.com/SoftwareBrothers/adminjs/commit/44f3999ef7f6
# 1930                                      https://github.com/source-academy/frontend/commit/4320231ee417
# 0                                                https://github.com/ngrx/example-app/commit/5c706a33a9f4
# 853                                                https://github.com/latticexyz/mud/commit/43575821dd13
# 3076                                https://github.com/microsoft/pxt-common-packages/commit/678f8d507b4c
# 497                                                https://github.com/microsoft/VoTT/commit/03e9cb87c3f8
# 475                                          https://github.com/terra-money/terra.js/commit/5c0a18d3ca8a
# 3126                                            https://github.com/remirror/remirror/commit/7d9f43837e7b
# 344                                                  https://github.com/laravel/echo/commit/8ab4b4343ac0
# 1040                                  https://github.com/GoogleChromeLabs/bubblewrap/commit/f48794d14d9c
# 1254                                              https://github.com/thirdweb-dev/js/commit/91f5a2fd5cb2
# 134                        https://github.com/microsoft/vscode-js-profile-visualizer/commit/9010c204c15e
# 2871                                           https://github.com/cognitedata/reveal/commit/36089911f8b5
# 3312                                              https://github.com/nestjs/terminus/commit/bac4854ad24b
# 115                                      https://github.com/1Password/connect-sdk-js/commit/d7681a6094c6
# 3821                                         https://github.com/balancer/frontend-v2/commit/b70a371e38f9
# 1647                        https://github.com/spring-cloud/spring-cloud-dataflow-ui/commit/a9619f5c5bdc
# 2731                                      https://github.com/counterfactual/monorepo/commit/f5aaf85449e5
# 2218                                    https://github.com/jupyterlab/jupyterlab-git/commit/dafc4006d5d3
# 1444                                              https://github.com/microsoft/tsdoc/commit/0bda30d601ec
# 554                                https://github.com/vitejs/vite-plugin-react-pages/commit/8018ab00c246
# 795                                         https://github.com/Azure/azure-cosmos-js/commit/0d38b3873b21
# 2510                      https://github.com/symbol/symbol-sdk-typescript-javascript/commit/654b1638ec36
# 1390                                        https://github.com/hwchase17/langchainjs/commit/f02042d899c9
# 2055                                           https://github.com/0xs34n/starknet.js/commit/34a977953c2b
# 361   https://github.com/microsoft/VerifiableCredentials-Verification-SDK-Typescript/commit/d9e1b8d50cbc
# 1590                                    https://github.com/safe-global/safe-core-sdk/commit/f5091e69e73e
# 3917                                               https://github.com/exadel-inc/esl/commit/38a3a54763a6
# 3384                                          https://github.com/puppeteer/puppeteer/commit/159d28354506
# 2117                                            https://github.com/telegraf/telegraf/commit/b6f4fba0c4b7
# 2169                                         https://github.com/uport-project/veramo/commit/63e64e0e2693
# 1170                                           https://github.com/magiclabs/magic-js/commit/45821755b214
# 3402                                            https://github.com/coder/code-server/commit/e8cd17a97d8c
# 681                                     https://github.com/farcasterxyz/hub-monorepo/commit/f12615d22b2f
# 2164                                   https://github.com/articodeltd/angular-cesium/commit/7ebc7493e7f0
# 3596                                  https://github.com/bitmovin/bitmovin-player-ui/commit/6618d3420121
# 1513                                 https://github.com/firebase/firebase-admin-node/commit/94dd7c3efb9f
# 2634                                             https://github.com/heremaps/harp.gl/commit/ab9bf5be20ce
# 2160                                        https://github.com/informalsystems/quint/commit/9287ae2a42cf
# 1414                                                https://github.com/MetaMask/core/commit/c7fd7db9ffe6
# 1588                                          https://github.com/harmonyland/harmony/commit/fe6930c06523
# 539                                    https://github.com/microsoft/iot-cardboard-js/commit/9eb874552d6c
# 256                                                https://github.com/Uniswap/v3-sdk/commit/2c8aa3a65383
# 1089                        https://github.com/microsoft/ApplicationInsights-node.js/commit/dd5684ce20c4
#
# [50 rows x 24 columns]

# %%
# For each in top_df, print:
# ###### i ######
# URL: commit_url
# Review: commit_msg
# Old version: old entire comment raw + old code raw
# New version: new entire comment raw + new code raw
for i in range(len(top_df)):
    row = top_df.iloc[i]
    print(f'###### {i + 1} ######')
    print(f'URL: {row.commit_url}')
    print(f'Review: {row.commit_msg}')
    print(f'Old version:\n{row.old_entire_comment_raw}\n{row.old_code_raw}')
    print(f'New version:\n{row.new_entire_comment_raw}\n{row.new_code_raw}')
    print()
# Out:
# ###### 1 ######
# URL: https://github.com/oceanprotocol/ocean.js/commit/9bf71ba4f078
# Review: Features/ethers (#1696)
#
# * add ethers
#
# * global updates
#
# * ve updates
#
# * ve tests
#
# * contract updates
#
# * first test passing
#
# * downgrade to ethers 5.7.2
#
# * add log
#
# * add tx wait
#
# * full NftFactory.test
#
# * add wait
#
# * add Router tests
#
# * fix dispenser
#
# * Nft test
#
# * add dispenser tests
#
# * add fre tests part 1
#
# * WIP datatoken unit tests
#
# * add DFRewards test
#
# * increase gas estimate
#
# * increase gas estimate
#
# * Work datatoken unit tests
#
# * datatoken test more tests
#
# * finished datatoken tests
#
# * fix nft get data
#
# * fix nft transfer tests
#
# * Provider int tests
#
# * Updating CodeExamples.md
#
# * update provider & fix publish flow int test
#
# * wip publish edit consume integration test
#
# * more work on  publish edit consume integration test
#
# * fix edit  publish edit consume integration test
#
# * add 3 int tests
#
# * Updating ComputeExamples.md
#
# * fix signature and download
#
# * fix compute flow integration test
#
# * udapte handleComputeOrder helper
#
# * update datatoken instance
#
# * update datatoken global variable
#
# * mint ocean tokens to consumer as well and added logs
#
# * update compute exammples
#
# * Updating ComputeExamples.md
#
# * wip code examples readme
#
# * update code examples readme
#
# * Updating CodeExamples.md
#
# * run all tests
#
# * update dep in readme
#
# * update readme
#
# * code examples update metadata flags
#
# * update dt instance in code examples md
#
# * set metadata updates
#
# * Updating CodeExamples.md
#
# * update code examples readme structure
#
# * Updating CodeExamples.md
#
# * update readmes table links
#
# * Updating CodeExamples.md
#
# * Updating ComputeExamples.md
#
# * clean-up
#
# * Updating CodeExamples.md
#
# * added missing unit tests for usdc fixed rate exchange tests
#
# * more cleanup and jsdoc updates
#
# * more  jsdoc updates
#
# * donw with jsdoc updates
#
# * handle provider errors
#
# * add missing error handling file
#
# * adds most of the provider errors
#
# * update get compute env return type
#
# * Release 3.0.0-next.0
#
# * adding Typedoc to ethers branch
#
# * update provider signature message
#
# * fix lint
#
# * Release 3.0.0-next.1
#
# * fix lint
#
# * adding Typedoc to ethers branch
#
# * Updating CI to build and commit the documentation
#
# * Updating documentation
#
# * Updating script permissions
#
# * fix todos add missing logic to send tx
#
# * npm package cleanups
#
# * Release 3.0.0-next.2
#
# * update log messages for errors
#
# * Release 3.0.0-next.3
#
# * fix gasFee issue on sendTx
#
# * Release 3.0.0-next.4
#
# * add consume params typings (#1731)
#
# * fix gas fee estimate
#
# * remove comments
#
# * add some delays before resolving datasets
#
# * adds delay to Publish flow tests
#
# * Release 3.0.0-next.5
#
# ---------
#
# Co-authored-by: Bogdan Fazakas <bogdan.fazakas@gmail.com>
# Co-authored-by: GitHub Actions Bot <>
# Co-authored-by: Jamie Hewitt <jamie.hewitt15@gmail.com>
# Co-authored-by: Jamie Hewitt <jamie@oceanprotocol.com>
# Old version:
# /**
#  * Returns the service endpoints that exist in provider.
#  * @param {any} endpoints
#  * @return {Promise<ServiceEndpoint[]>}
#  */
# public async getServiceEndpoints(providerEndpoint: string, endpoints: any) {
#   const serviceEndpoints: ServiceEndpoint[] = []
#   for (const i in endpoints.serviceEndpoints) {
#     const endpoint: ServiceEndpoint = {
#       serviceName: i,
#       method: endpoints.serviceEndpoints[i][0],
#       urlPath: providerEndpoint + endpoints.serviceEndpoints[i][1]
#     }
#     serviceEndpoints.push(endpoint)
#   }
#   return serviceEndpoints
# }
# New version:
# /**
#  * This function returns an array of service endpoints for a given provider endpoint.
#  * @param {string} providerEndpoint - The provider endpoint
#  * @param {any} endpoints - The endpoints object
#  * @returns {ServiceEndpoint[]} An array of service endpoints
#  */
# public async getServiceEndpoints(providerEndpoint: string, endpoints: any) {
#   const serviceEndpoints: ServiceEndpoint[] = []
#   for (const i in endpoints.serviceEndpoints) {
#     const endpoint: ServiceEndpoint = {
#       serviceName: i,
#       method: endpoints.serviceEndpoints[i][0],
#       urlPath: providerEndpoint + endpoints.serviceEndpoints[i][1]
#     }
#     serviceEndpoints.push(endpoint)
#   }
#   return serviceEndpoints
# }
#
# ###### 2 ######
# URL: https://github.com/microsoft/botbuilder-js/commit/6e1009b256f3
# Review: adjusted override/callback docstrings (#2902)
#
# * adjusted override/callback docstrings
#
# * typo fix
#
# Co-authored-by: Michael Richardson <v-micric@microsoft.com>
# Old version:
# /**
#  * Override this in a derived class to provide logic for when a team is deleted.
#  * @param handler
#  * @returns A promise that represents the work queued.
#  */
# public onTeamsTeamDeletedEvent(
#     handler: (teamInfo: TeamInfo, context: TurnContext, next: () => Promise<void>) => Promise<void>
# ): this {
#     return this.on('TeamsTeamDeleted', async (context, next) => {
#         const teamsChannelData = context.activity.channelData as TeamsChannelData;
#         await handler(teamsChannelData.team, context, next);
#     });
# }
# New version:
# /**
#  * Registers a handler for TeamsTeamDeleted events, such as for when a team is deleted.
#  * @param handler
#  * @returns A promise that represents the work queued.
#  */
# public onTeamsTeamDeletedEvent(
#     handler: (teamInfo: TeamInfo, context: TurnContext, next: () => Promise<void>) => Promise<void>
# ): this {
#     return this.on('TeamsTeamDeleted', async (context, next) => {
#         const teamsChannelData = context.activity.channelData as TeamsChannelData;
#         await handler(teamsChannelData.team, context, next);
#     });
# }
#
# ###### 3 ######
# URL: https://github.com/readmeio/api/commit/18ddbfb223b5
# Review: feat: completely overhauling how we're handling response data (#539)
#
# * feat: allowing `accept` headers to always be sent through as metadata
#
# * chore: removing some unnecessary comments
#
# * fix: adding an sdk integration test for accept headers
#
# * feat: completely overhauling how we're handling response data
#
# * chore: lockfile updates
#
# * fix: removing duped code
#
# * fix: broken test
#
# * fix: broken tests
#
# * fix: updating code snippets for new syntax
#
# * fix: updating snippet generation to use operation ids now
# Old version:
# /**
#  * Optionally configure various options, such as response parsing, that the SDK allows.
#  *
#  * @param config Object of supported SDK options and toggles.
#  * @param config.parseResponse If responses are parsed according to its `Content-Type` header.
#  */
# config(config: ConfigOptions) {
#   this.core.setConfig(config);
# }
# New version:
# /**
#  * Optionally configure various options that the SDK allows.
#  *
#  * @param config Object of supported SDK options and toggles.
#  */
# config(config: ConfigOptions) {
#   this.core.setConfig(config);
# }
#
# ###### 4 ######
# URL: https://github.com/apify/fingerprint-suite/commit/9d32a69b3eca
# Review: JSDoc update, TS fixups
# Old version:
# /**
#  * Randomly samples from the distribution represented by the bayesian network,
#  * making sure the sample is consistent with the provided restrictions on value possibilities.
#  * Returns false if no such sample can be generated.
#  * @param {object} valuePossibilities - a dictionary of lists of possible values for nodes
#  *                                      (if a node isn't present in the dictionary, all values are possible)
#  */
# generateConsistentSampleWhenPossible(valuePossibilities: Record<string, string[]>) {
#     return this.recursivelyGenerateConsistentSampleWhenPossible({}, valuePossibilities, 0);
# }
# New version:
# /**
#  * Randomly samples values from the distribution represented by the bayesian network,
#  * making sure the sample is consistent with the provided restrictions on value possibilities.
#  * Returns false if no such sample can be generated.
#  * @param valuePossibilities A dictionary of lists of possible values for nodes (if a node isn't present in the dictionary, all values are possible).
#  */
# generateConsistentSampleWhenPossible(valuePossibilities: Record<string, string[]>) {
#     return this.recursivelyGenerateConsistentSampleWhenPossible({}, valuePossibilities, 0);
# }
#
# ###### 5 ######
# URL: https://github.com/mapillary/mapillary-js/commit/99f65410ee95
# Review: docs: fix links and event tags
#
# Tag event types with event jsdoc tag.
# Remove event tag from event interfaces
# to enable full info in the docs.
# Old version:
# /**
#  * Get image tiles urls for a single tile or
#  * a tile level.
#  *
#  * @param {ImageTilesRequestContract} tiles - Tiles to request
#  * @returns {Promise<ImageTilesContract>} Promise to the
#  * image tiles response contract
#  * @throws {Error} Rejects the promise on errors.
#  *
#  * @example
#  * ```js
#  * var singleTile = { imageId: 'image-id', x: 0, y: 0, z: 12 };
#  * provider.getImageTiles(singleTile)
#  *   .then((response) => console.log(response));
#  *
#  * var tileLevel = { imageId: 'image-id', z: 12 };
#  * provider.getImageTiles(tileLevel)
#  *   .then((response) => console.log(response));
#  * ```
#  */
# public getImageTiles(
#     tiles: ImageTilesRequestContract): Promise<ImageTilesContract> {
#     return Promise.reject(new MapillaryError("Not implemented"));
# }
# New version:
# /**
#  * Get image tiles urls for a tile level.
#  *
#  * @param {ImageTilesRequestContract} tiles - Tiles to request
#  * @returns {Promise<ImageTilesContract>} Promise to the
#  * image tiles response contract
#  *
#  * @throws Rejects the promise on errors.
#  *
#  * @example
#  * ```js
#  * var tileRequest = { imageId: 'image-id', z: 12 };
#  * provider.getImageTiles(tileRequest)
#  *   .then((response) => console.log(response));
#  * ```
#  */
# public getImageTiles(
#     tiles: ImageTilesRequestContract): Promise<ImageTilesContract> {
#     return Promise.reject(new MapillaryError("Not implemented"));
# }
#
# ###### 6 ######
# URL: https://github.com/Adyen/adyen-web/commit/d5828f2d98c6
# Review: Add eslint-plugin-tsdoc (#50)
#
# * Add TSDoc linting
#
# * Fix linting issues on TSDoc comments
# Old version:
# /**
#  * Returns a translated string from a key and a locale
#  * @param {string} key
#  * @return {string}
#  */
# get(key: string): string {
#     const translation = getTranslation(this.translations, key);
#     if (translation !== null) {
#         return translation;
#     }
#
#     return key;
# }
# New version:
# /**
#  * Returns a translated string from a key in the current {@link Language.locale}
#  * @param key - Translation key
#  * @returns Translated string
#  */
# get(key: string): string {
#     const translation = getTranslation(this.translations, key);
#     if (translation !== null) {
#         return translation;
#     }
#
#     return key;
# }
#
# ###### 7 ######
# URL: https://github.com/SoftwareBrothers/adminjs/commit/44f3999ef7f6
# Review: Collective resolve of GitHub issues (#989)
#
# * fix: fixed filters autocomplete from url on initial page enter (#988)
#
# * fix: update doc comment for listUrl method
#
# * fix: look over for valid component extension if not specified
#
# * chore: added skip lib property to typescript (#994)
#
# * feat: add property description (#990)(@justusburger @ariansobczak-rst)
#
# * feat: add description field
#
# Add description field
#
# * feat: added property description as hoverable icon in property label
#
# * chore: fixed PropertyDecorator tests
#
# * chore: fix cr issues
#
# * chore: fix cr issues
#
# * chore: introduced localize description
#
# Co-authored-by: Justus Burger <justus.burger@klarna.com>
#
# Co-authored-by: Przemysław Szejna <przemyslaw.szejna@softwarebrothers.co>
# Co-authored-by: Przemysław Szejna <60508566+przemyslaw-szejna-sb@users.noreply.github.com>
# Co-authored-by: Justus Burger <justus.burger@klarna.com>
# Old version:
# /**
#  * Returns url for a `new` action in given Resource. Uses {@link resourceActionUrl}
#  *
#  * @param {string} resourceId  id to the resource
#  * @param {string} [search]        optional query string
#  */
# listUrl(resourceId: string, search?: string): string {
#   return this.resourceActionUrl({ resourceId, actionName: 'list', search })
# }
# New version:
# /**
#  * Returns url for a `list` action in given Resource. Uses {@link resourceActionUrl}
#  *
#  * @param {string} resourceId  id to the resource
#  * @param {string} [search]        optional query string
#  */
# listUrl(resourceId: string, search?: string): string {
#   return this.resourceActionUrl({ resourceId, actionName: 'list', search })
# }
#
# ###### 8 ######
# URL: https://github.com/source-academy/frontend/commit/4320231ee417
# Review: Achievement: Refactor (Part 1) (#1447)
#
# * Edit mocks
#
# * Update view style
#
# * Code formatting, documentation
#
# * Update control handlers
#
# * Restructure achievement commons
#
# * WIP fix style, add goal editor container
#
# * Update platform & container styles
#
# * Correctly display control panel cards
#
# * Editable task div
#
# * Rename focusId
#
# * Implement achievement preview
#
# * Preview mimic actual height
#
# * Refactor achievements
#
# * Add display view
#
# * dereference mock when running with backend
# Old version:
# // NOTE: positions of achievements are 1-indexed.
# public changeAchievementPosition(achievement: AchievementItem, newPosition: number) {
#   const achievements = this.getAchievements()
#     .filter(achievement => achievement.isTask)
#     .sort((taskA, taskB) => taskA.position - taskB.position);
#
#   const targetAchievement = achievements.splice(achievement.position - 1, 1)[0];
#   achievements.splice(newPosition - 1, 0, targetAchievement);
#
#   for (let i = Math.min(newPosition - 1, achievement.position); i < achievements.length; i++) {
#     const editedAchievement = achievements[i];
#     editedAchievement.position = i + 1;
#   }
# }
# New version:
# /**
#  * Changes the position of the achievement
#  *
#  * Note: positions of achievements are 1-indexed
#  *
#  * @param achievement the AchievementItem
#  * @param newPosition the new position
#  */
# public changeAchievementPosition(achievement: AchievementItem, newPosition: number) {
#   const achievements = this.getAchievements()
#     .filter(achievement => achievement.isTask)
#     .sort((taskA, taskB) => taskA.position - taskB.position);
#
#   const targetAchievement = achievements.splice(achievement.position - 1, 1)[0];
#   achievements.splice(newPosition - 1, 0, targetAchievement);
#
#   for (let i = Math.min(newPosition - 1, achievement.position); i < achievements.length; i++) {
#     const editedAchievement = achievements[i];
#     editedAchievement.position = i + 1;
#   }
# }
#
# ###### 9 ######
# URL: https://github.com/ngrx/example-app/commit/5c706a33a9f4
# Review: Add more documentation, fix a few bugs
# Old version:
# /**
#  * This method creates an observable that waits for the `loaded` property
#  * of the collection to turn `true`, emitting one time once loading
#  * has finished.
#  */
# waitForCollectionToLoad() {
#   return this.store.let(getCollectionLoaded())
#     .filter(loaded => loaded)
#     .take(1);
# }
# New version:
# /**
#  * This method creates an observable that waits for the `loaded` property
#  * of the collection state to turn `true`, emitting one time once loading
#  * has finished.
#  */
# waitForCollectionToLoad() {
#   return this.store.let(getCollectionLoaded())
#     .filter(loaded => loaded)
#     .take(1);
# }
#
# ###### 10 ######
# URL: https://github.com/latticexyz/mud/commit/43575821dd13
# Review: docs: add documentation (#129)
#
# * build: change docs action to use alvrs/realdocs as base branch
#
# * docs(recs): add documentation
#
# * docs(recs): add documentation
#
# * docs(recs): add documentation
#
# * docs: add ECS introduction
#
# * docs(recs): update README.md
#
# * docs(solecs): add draft for README.md
#
# * docs(solecs): update README.md
#
# * docs(solecs): remove redundant headline
#
# * docs(solecs): add docs for Component.sol
#
# * docs(solecs): add code documentation
#
# * docs(network): add README.md
#
# * docs(network): add network documentation
#
# * build: fix type generation with new forge version
#
# * build: publish public folder
#
# * build: publish docs when pushing to main
# Old version:
# // For positive fragments (Has/HasValue) we need to find any passing entity up the proxy chain
# // so as soon as passes is true, we can early return. For negative fragments (Not/NotValue) every entity
# // up the proxy chain must pass, so we can early return if we find one that doesn't pass.
# function isBreakingPassState(passes: boolean, fragment: EntityQueryFragment<Schema>) {
#   return (passes && isPositiveFragment(fragment)) || (!passes && isNegativeFragment(fragment));
# }
# New version:
# /**
#  * Helper function to check whether the result of a query pass check is a breaking state.
#  *
#  * @remarks
#  * For positive fragments (Has/HasValue) we need to find any passing entity up the proxy chain
#  * so as soon as passes is true, we can early return. For negative fragments (Not/NotValue) every entity
#  * up the proxy chain must pass, so we can early return if we find one that doesn't pass.
#  *
#  * @param passes Boolean result of previous query pass check.
#  * @param fragment Fragment that was used in the query pass check.
#  * @returns True if the result is breaking pass state, else false.
#  */
# function isBreakingPassState(passes: boolean, fragment: EntityQueryFragment<Schema>) {
#   return (passes && isPositiveFragment(fragment)) || (!passes && isNegativeFragment(fragment));
# }
#
# ###### 11 ######
# URL: https://github.com/microsoft/pxt-common-packages/commit/678f8d507b4c
# Review: Physics interpolation (#879)
#
# * move min/max speeds to properties on physics class
#
# * temporarily re-space for readability, fx.1/2 constant
#
# * helper functions for overlap handlers, colliding sprites
#
# * remove unnecessary param for moveSprite
#
# * don't re-evaluate tile scale / size for each sprite
#
# * refactor horizontal / vertical collisions into helper functions
#
# * temporarily move sprite handling below helper functions to workaround scope issue
#
# * fix destroy on wall
#
# * clean static obstacle creation
#
# * invoke all collision handlers at the same time (wait till all evaled to run in parallel)
#
# * inline helper function
#
# error at runtime due to ordering of helper functions that was more trouble than minor redundancy
#
# * remove deprecated single sprite overlap event, inline helper
#
# * merge move and collisions to one frame handler
#
# * only check events relevant to given sprites; SparseArray interface
#
# * pre compute move diffs
#
# * fix sprite z index
#
# * begin interpolating (sloooooow)
#
# * raise step size and store ref to handlers on sprite
#
# * just use map
#
# * always make sprite map
#
# * interpolation (slloooooww)
#
# * only check tmap collisions of moving sprites
#
# * inline tilemap collision helpers
#
# * move helper to method, clean up collision logic slightly (temporarily break bounce on walls)
#
# * fix bounce on walls
#
# * poll scene less often
#
# * invoke events on each step rather than all at once
#
# * make max step configurable
#
# * lower default increment
#
# * fix bug in jumpy platformer
#
# * always count collisions as obstacles, don't filter out non moving sprites
#
# * set spr velocities to 0 on contact with walls
#
# * inline collisions helper, only check overlaps when a sprite moves
#
# * bugs bugs bugs
#
# * only clear obstacles if the sprite is moving
#
# * only update spritemap as needed; semi fix on tile hit (broken if sprite initially adjacent to tile)
#
# * clean up, better spritemap behavior, reorder scene events
#
# * track kinds overlapped for perf
#
# * only clear tile obstacles when moving in axis against them
#
# * remove legacy tile collision api
#
# * more efficient collision handlers resolution
#
# * remove redundant checks and more lenient tile obstacle creation
#
# * double buffer to fix 841 error with paint brush @ 2k velocities
#
# * invoke overlap events immediately to avoid mem issues
#
# * use fx8 const
#
# * configurable min step, unbreak step size
#
# * respect velocities that change sub movement
#
# * skip overlap if other sprite has become a ghost
#
# * clean up some flags, add max step count
#
# * leading runInParallel, slice handlers
#
# * lint
#
# * remove some dead code
#
# * always clear collisions when moving
#
# * don't crash on particles
#
# * fix tmap collisions
#
# * add min gap to avoid trivial movements
#
# * more accurate max step count
#
# * fix wall bounce at high speed
#
# * add some quick documentation about what different steps are doing
#
# * just call Fx8 on 1/2 instead of casting
#
# * MovingSprite interface->class
# Old version:
# /** Apply physics */
# move(dt: number) { }
# New version:
# /** Apply physics and collisions */
# move(dt: number) { }
#
# ###### 12 ######
# URL: https://github.com/microsoft/VoTT/commit/03e9cb87c3f8
# Review: TFRecords exporter (#495)
#
# * WIG using TFRecord package
#
# * Testing Protocol Buffer generation
#
# * WIP Adding support for TFRecords ProtoBuf main containers
#
# * WIP Adding internal methods for TFRecord Features
#
# * WIP saving base64 and sha256 in TFRecords
#
# * get asset tags/region
#
# * WIP saving on TFRecords feature arrays
#
# * Exported Features and FeatureLists on TFRecords
#
# * WIG using TFRecord package
#
# * Testing Protocol Buffer generation
#
# * WIP Adding support for TFRecords ProtoBuf main containers
#
# * WIP Adding internal methods for TFRecord Features
#
# * WIP saving base64 and sha256 in TFRecords
#
# * get asset tags/region
#
# * WIP saving on TFRecords feature arrays
#
# * Exported Features and FeatureLists on TFRecords
#
# * removed test tag data
#
# * update tests
#
# * replaced string to utf-8 bytearray with custom implementation
#
# * testing also pbtxt file
#
# * excluded protocol buffer generated js file in codeconv
#
# * rename TFRecord/ProtoBuf features object
#
# * Added CRC to TFRecords
#
# * Added 32bit and 64bit CRCs
#
# * fix crc masking
#
# * Write all Int in Low Endian
#
# * Adding CRC to Buffer reusing V1 code
#
# * try different crc package (buffer-crc32)
#
# * Added TFRecords Helper file with utility methods for CRC and Buffer conversion
#
# * Added unit tests for TFRecords Helper functions
#
# * Fix Image encoding in TFRecords
#
# * Refactored asset image download
#
# * Added small comment on TFRecords write catch
#
# * Export tag index position too
#
# * Fix TFRecords features persistence
#
# * Fixed last TFRecords features
# Old version:
# /**
#  * Downloads the binary blob from the blob path
#  * @param asset The asset to download
#  */
# public static async getAssetBlob(asset: IAsset): Promise<Blob> {
#     Guard.null(asset);
#
#     const config: AxiosRequestConfig = {
#         responseType: "blob",
#     };
#
#     // Download the asset binary from the storage provider
#     const response = await axios.get<Blob>(asset.path, config);
#     if (response.status !== 200) {
#         throw new Error("Error downloading asset binary");
#     }
#
#     return response.data;
# }
# New version:
# /**
#  * Downloads the binary blob from the asset path
#  * @param asset The asset to download
#  */
# public static async getAssetBlob(asset: IAsset): Promise<Blob> {
#     Guard.null(asset);
#
#     const config: AxiosRequestConfig = {
#         responseType: "blob",
#     };
#
#     // Download the asset binary from the storage provider
#     const response = await axios.get<Blob>(asset.path, config);
#     if (response.status !== 200) {
#         throw new Error("Error downloading asset binary");
#     }
#
#     return response.data;
# }
#
# ###### 13 ######
# URL: https://github.com/terra-money/terra.js/commit/5c0a18d3ca8a
# Review: fix comments for broadcastSync/Async
# Old version:
# /**
#  * Broadcast the transaction using the "async" mode, returning after CheckTx() is performed.
#  * @param tx transaction to broadcast
#  */
# public async broadcastAsync(tx: Tx): Promise<AsyncTxBroadcastResult> {
#   return this._broadcast<{ tx_response: AsyncTxBroadcastResult.Data }>(
#     tx,
#     'BROADCAST_MODE_ASYNC'
#   ).then(({ tx_response: d }) => ({
#     height: +d.height,
#     txhash: d.txhash,
#   }));
# }
# New version:
# /**
#  * Broadcast the transaction using the "async" mode, returns immediately (transaction might fail).
#  * @param tx transaction to broadcast
#  */
# public async broadcastAsync(tx: Tx): Promise<AsyncTxBroadcastResult> {
#   return this._broadcast<{ tx_response: AsyncTxBroadcastResult.Data }>(
#     tx,
#     'BROADCAST_MODE_ASYNC'
#   ).then(({ tx_response: d }) => ({
#     height: +d.height,
#     txhash: d.txhash,
#   }));
# }
#
# ###### 14 ######
# URL: https://github.com/remirror/remirror/commit/7d9f43837e7b
# Review: fix(extension-callout): prevent empty block containers (#937)
#
# * fix(extension-callout): empty callouts should not be valid
#
# * fix(extension-callout): callout message should select on type attribute
#
# * chore(callout-extension): update deprecated comment hints
#
# * fix(extension-blockquote): empty blockquotes should not be valid
#
# * fix(extension-callout): validate callout type in parseDOM
# Old version:
# /**
#  * Create an input rule that listens converts the code fence into a code block
#  * when typing triple back tick followed by a space.
#  */
# createInputRules(): InputRule[] {
#   return [
#     nodeInputRule({
#       regexp: /^:::([\dA-Za-z]*) $/,
#       type: this.type,
#       beforeDispatch: ({ tr, start }) => {
#         const $pos = tr.doc.resolve(start);
#         tr.setSelection(new TextSelection($pos));
#       },
#       getAttributes: (match) => {
#         const { defaultType, validTypes } = this.options;
#         return { type: getCalloutType(getMatchString(match, 1), validTypes, defaultType) };
#       },
#     }),
#   ];
# }
# New version:
# /**
#  * Create an input rule that listens for input of 3 colons followed
#  * by a valid callout type, to create a callout node
#  * If the callout type is invalid, the defaultType callout is created
#  */
# createInputRules(): InputRule[] {
#   return [
#     nodeInputRule({
#       regexp: /^:::([\dA-Za-z]*) $/,
#       type: this.type,
#       beforeDispatch: ({ tr, start }) => {
#         const $pos = tr.doc.resolve(start);
#         tr.setSelection(new TextSelection($pos));
#       },
#       getAttributes: (match) => {
#         const { defaultType, validTypes } = this.options;
#         return { type: getCalloutType(getMatchString(match, 1), validTypes, defaultType) };
#       },
#     }),
#   ];
# }
#
# ###### 15 ######
# URL: https://github.com/laravel/echo/commit/8ab4b4343ac0
# Review: Fixes comment
# Old version:
# /**
#  * Register jQuery AjaxSetup to add the X-Socket-ID header.
#  */
# registerjQueryAjaxSetup(): void {
#     if (typeof jQuery.ajax != 'undefined') {
#         jQuery.ajaxPrefilter((options, originalOptions, xhr) => {
#             if (this.socketId()) {
#                 xhr.setRequestHeader('X-Socket-Id', this.socketId());
#             }
#         });
#     }
# }
# New version:
# /**
#  * Register jQuery AjaxPrefilter to add the X-Socket-ID header.
#  */
# registerjQueryAjaxSetup(): void {
#     if (typeof jQuery.ajax != 'undefined') {
#         jQuery.ajaxPrefilter((options, originalOptions, xhr) => {
#             if (this.socketId()) {
#                 xhr.setRequestHeader('X-Socket-Id', this.socketId());
#             }
#         });
#     }
# }
#
# ###### 16 ######
# URL: https://github.com/GoogleChromeLabs/bubblewrap/commit/f48794d14d9c
# Review: Install the GPP plugin into the template project. (#491)
#
# * Install the GPP plugin into the template project.
#
# This installs the GPP plugin into the template project. This will apply
# the configuration files serviceAccountJson key to the specified files
# which will activate the GPP plugin.
#
# * Change zipalign command from writing the file to validating alignment.
#
# This changes the zip align command from aligning the file to checking
# alignment only. This is based off the information provided in :
# https://b.corp.google.com/issues/162117652
# and
# https://github.com/microsoft/azure-pipelines-tasks/issues/13863
# The Android Gradle Plugin automatically aligns APKs now and is no longer
# needed to align APKs (based on this comment):
# https://b.corp.google.com/issues/162117652#comment12
#
# * Fix my lints
#
# * Add a space between comment start and word.
#
# * Changed serviceAccountJson to serviceAccountJsonFile.
#
# This makes the new field more descriptive of what it actually stores.
#
# * Change serviceAccountJson to serviceAccountJsonFile in build.gradle.
#
# * Added documentation regarding the zipalign flags used.
#
# * Add a zipalignOnlyVerification method for validating zip alignment.
#
# * Lint fix
#
# * Update code comment to reflect variable name
#
# This updates the code comments to reflect the correct variable name in the code comments.
#
# * Moved the copy step of zipalign to build.ts
#
# This moves the copy step of the zipalignOnlyVerification to the build
# file instead.
#
# * Removed no longer needed parameter.
# Old version:
# /**
#  * Invokes the zipalign tool from the Android SDK
#  * @param {string} input path to the input file.
#  * @param {string} output path to the output file.
#  */
# async zipalign(input: string, output: string): Promise<void> {
#   const env = this.getEnv();
#   const zipalignCmd = [
#     `"${this.pathJoin(this.getAndroidHome(), `/build-tools/${BUILD_TOOLS_VERSION}/zipalign`)}"`,
#     '-v -f -p 4',
#     input,
#     output,
#   ];
#   await util.execute(zipalignCmd, env);
# }
# New version:
# /**
#  * Invokes the zipalign tool from the Android SDK with the following flags:
#  *  -f   : overwrite existing outfile.zip.
#  *  -v   : verbose output.
#  *  -p 4 : align all libraries to the 32-bit page boundary.
#  * More information on zipalign can be found here:
#  *  https://developer.android.com/studio/command-line/zipalign
#  * @param {string} input path to the input file.
#  * @param {string} output path to the output file.
#  */
# async zipalign(input: string, output: string): Promise<void> {
#   const env = this.getEnv();
#   const zipalignCmd = [
#     `"${this.pathJoin(this.getAndroidHome(), `/build-tools/${BUILD_TOOLS_VERSION}/zipalign`)}"`,
#     '-v -f -p 4',
#     input,
#     output,
#   ];
#   await util.execute(zipalignCmd, env);
# }
#
# ###### 17 ######
# URL: https://github.com/thirdweb-dev/js/commit/91f5a2fd5cb2
# Review: Fix documentation for react docs (#626)
# Old version:
# /**
#  * Get Owned NFTs
#  *
#  * @remarks Get all the data associated with the NFTs owned by a specific wallet.
#  *
#  * @example
#  * ```javascript
#  * // Address of the wallet to get the NFTs of
#  * const address = "{{wallet_address}}";
#  * const nfts = await contract.nft.query.owned.all(address);
#  * ```
#  * @param walletAddress - the wallet address to query, defaults to the connected wallet
#  * @returns The NFT metadata for all NFTs in the contract.
#  */
# public async all(walletAddress?: string): Promise<NFT[]> {
#   const tokenIds = await this.tokenIds(walletAddress);
#   return await Promise.all(
#     tokenIds.map((tokenId) => this.erc721.get(tokenId.toString())),
#   );
# }
# New version:
# /**
#  * Get all NFTs owned by a specific wallet
#  *
#  * @remarks Get all the data associated with the NFTs owned by a specific wallet.
#  *
#  * @example
#  * ```javascript
#  * // Address of the wallet to get the NFTs of
#  * const address = "{{wallet_address}}";
#  * const nfts = await contract.nft.query.owned.all(address);
#  * ```
#  * @param walletAddress - the wallet address to query, defaults to the connected wallet
#  * @returns The NFT metadata for all NFTs in the contract.
#  */
# public async all(walletAddress?: string): Promise<NFT[]> {
#   const tokenIds = await this.tokenIds(walletAddress);
#   return await Promise.all(
#     tokenIds.map((tokenId) => this.erc721.get(tokenId.toString())),
#   );
# }
#
# ###### 18 ######
# URL: https://github.com/microsoft/vscode-js-profile-visualizer/commit/9010c204c15e
# Review: chore: fix comment
# Old version:
# /**
#  * Adds a new code lens at the given location in the file.
#  */
# protected set(file: string, position: Position, data: ITreeNode) {
#   let list = this.data.get(lowerCaseInsensitivePath(file));
#   if (!list) {
#     list = [];
#     this.data.set(lowerCaseInsensitivePath(file), list);
#   }
#
#   let index = 0;
#   while (index < list.length && list[index].position.line < position.line) {
#     index++;
#   }
#
#   if (list[index]?.position.line === position.line) {
#     const existing = list[index];
#     if (position.character < existing.position.character) {
#       existing.position = new Position(position.line, position.character);
#     }
#     existing.data.totalSize += data.totalSize;
#     existing.data.selfSize += data.selfSize;
#   } else {
#     list.splice(index, 0, {
#       position: new Position(position.line, position.character),
#       data: {
#         totalSize: data.totalSize,
#         selfSize: data.selfSize,
#       },
#     });
#   }
# }
# New version:
# /**
#  * Adds a new code lens at the given treeNode in the file.
#  */
# protected set(file: string, position: Position, data: ITreeNode) {
#   let list = this.data.get(lowerCaseInsensitivePath(file));
#   if (!list) {
#     list = [];
#     this.data.set(lowerCaseInsensitivePath(file), list);
#   }
#
#   let index = 0;
#   while (index < list.length && list[index].position.line < position.line) {
#     index++;
#   }
#
#   if (list[index]?.position.line === position.line) {
#     const existing = list[index];
#     if (position.character < existing.position.character) {
#       existing.position = new Position(position.line, position.character);
#     }
#     existing.data.totalSize += data.totalSize;
#     existing.data.selfSize += data.selfSize;
#   } else {
#     list.splice(index, 0, {
#       position: new Position(position.line, position.character),
#       data: {
#         totalSize: data.totalSize,
#         selfSize: data.selfSize,
#       },
#     });
#   }
# }
#
# ###### 19 ######
# URL: https://github.com/cognitedata/reveal/commit/36089911f8b5
# Review: add eslint-plugin-jsdoc (#1107)
#
# * chore(viewer): add eslint-plugin-jsdoc
#
# * chore(viewer): fix every jsdoc error
#
# * fix(Cognite3DModel): proper use of await in async fns
# Old version:
# /**
#  * Set camera's target
#  * @public
#  * @param target Target in world space
#  * @example
#  * ```js
#  * // store position, target
#  * const position = viewer.getCameraPosition();
#  * const target = viewer.getCameraTarget();
#  * // restore position, target
#  * viewer.setCameraPosition(position);
#  * viewer.setCameraTarget(target);
#  * ```
#  */
# setCameraTarget(target: THREE.Vector3): void {
#   if (this.isDisposed) {
#     return;
#   }
#   this.controls.setState(this.getCameraPosition(), target);
# }
# New version:
# /**
#  * Set camera's target.
#  * @public
#  * @param target Target in world space.
#  * @example
#  * ```js
#  * // store position, target
#  * const position = viewer.getCameraPosition();
#  * const target = viewer.getCameraTarget();
#  * // restore position, target
#  * viewer.setCameraPosition(position);
#  * viewer.setCameraTarget(target);
#  * ```
#  */
# setCameraTarget(target: THREE.Vector3): void {
#   if (this.isDisposed) {
#     return;
#   }
#   this.controls.setState(this.getCameraPosition(), target);
# }
#
# ###### 20 ######
# URL: https://github.com/nestjs/terminus/commit/bac4854ad24b
# Review: fix(disk): Fix jsdoc comment on check method
# Old version:
# /**
#  * Checks if the given url respons in the given timeout
#  * and returns a result object corresponding to the result
#  * @param key The key which will be used for the result object
#  *
#  * @throws {HealthCheckError} In case the health indicator failed
#  * @throws {DiskStorageExceededError} In case the disk storage has exceeded the given threshold
#  *
#  * @returns {Promise<HealthIndicatorResult>} The result of the health indicator check
#  *
#  * @example
#  * diskHealthIndicator.checkStorage('storage', { threshold: 120000000000, path: '/' });
#  * @example
#  * diskHealthIndicator.checkSotrage('storage', { thresholdPercent: 0.5, path: 'C:\\' });
#  */
# async check(
#   key: string,
#   options: DiskHealthIndicatorOptions,
# ): Promise<HealthIndicatorResult> {
#   return await this.checkStorage(key, options);
# }
# New version:
# /**
#  * Checks if the size of the given size has exceeded the
#  * given threshold
#  *
#  * @param key The key which will be used for the result object
#  *
#  * @throws {HealthCheckError} In case the health indicator failed
#  * @throws {DiskStorageExceededError} In case the disk storage has exceeded the given threshold
#  *
#  * @returns {Promise<HealthIndicatorResult>} The result of the health indicator check
#  *
#  * @example
#  * // The used disk storage should not exceed 250 GB
#  * diskHealthIndicator.check('storage', { threshold: 250 * 1024 * 1024 * 1024, path: '/' });
#  * @example
#  * // The used disk storage should not exceed 50% of the full disk size
#  * diskHealthIndicator.check('storage', { thresholdPercent: 0.5, path: 'C:\\' });
#  */
# async check(
#   key: string,
#   options: DiskHealthIndicatorOptions,
# ): Promise<HealthIndicatorResult> {
#   return await this.checkStorage(key, options);
# }
#
# ###### 21 ######
# URL: https://github.com/1Password/connect-sdk-js/commit/d7681a6094c6
# Review: fixed pr comments
# Old version:
# /**
#  * Get metadata about a single vault
#  *
#  * @param vaultId
#  */
# public async getVaultById(vaultId: string): Promise<Vault> {
#     const { data } = await this.adapter.sendRequest(
#         "get",
#         `${this.basePath}/${vaultId}`,
#     );
#     return ObjectSerializer.deserialize(data, "Vault");
# }
# New version:
# /**
#  * Get metadata about a single vault with the provided ID.
#  *
#  * @param {string} vaultId
#  */
# public async getVaultById(vaultId: string): Promise<Vault> {
#     const { data } = await this.adapter.sendRequest(
#         "get",
#         `${this.basePath}/${vaultId}`,
#     );
#     return ObjectSerializer.deserialize(data, "Vault");
# }
#
# ###### 22 ######
# URL: https://github.com/balancer/frontend-v2/commit/b70a371e38f9
# Review: refactor: User staking (#2745)
#
# * feat: Add userData and userStaking providers
#
# * chore: Add computed props to user staking
#
# * refactor: Dirty commit
#
# * refactor: Make portfolio page work with userStakingProvider
#
# * refactor: Use pool staking in staking modal
#
# * fix: Tx summary
#
# * fix: Ensure all user pools a refertched after staking success
#
# * chore: Get portfolio pools to update as expected
#
# * fix: Labels
#
# * refactor: Approval labels
#
# * fix: Migration flow
#
# * feat: Make unstaking work on portfolio page
#
# * fix: Type error
#
# * chore: Remove old staking provider
#
# * fix: Remove old references to staking.provider
#
# * chore: Remove unused query
#
# * fix: Type errors
#
# * chore: Remove sleep
#
# * chore: Make relative import global
#
# * feat: Add helper function for amount labels
#
# * chore: Remove useStaking
#
# * chore: Remove watch
#
# * fix: Don't need to call refetch pools twice on portfolio page
#
# * chore: Remove comment
#
# * chore: Remove log
#
# * chore: Remove import
#
# * chore: Remove import
#
# * chore: Change method name
#
# * chore: Remove import
#
# * chore: Add comments
#
# * chore: Remove imports
#
# * chore: Add comments
#
# * chore: Remove optional chaining
#
# * chore: Remove optional chaining
# Old version:
# /**
#  * METHODS
#  */
# async function refetchAllPoolStakingData() {
#   return Promise.all([
#     refetchPoolGauges.value(),
#     refetchStakedShares.value(),
#     refetchUserGaugeShares.value(),
#     refetchUserBoosts.value(),
#   ]);
# }
# New version:
# // Triggers refetch of all queries in this provider.
# async function refetchAllPoolStakingData() {
#   return Promise.all([
#     refetchPoolGauges.value(),
#     refetchStakedShares.value(),
#     refetchUserGaugeShares.value(),
#     refetchUserBoosts.value(),
#   ]);
# }
#
# ###### 23 ######
# URL: https://github.com/spring-cloud/spring-cloud-dataflow-ui/commit/a9619f5c5bdc
# Review: gh-432 Port field-value-counter D3js widgets to Angular4 infrastructure
#
# * Migrate Pie chart component to Angular 4 and D3v4
#   - Add ability to define # of pie slices
#   - Add boolean flag wether to use all data to calculate`other` slice
# * Migrate Bubble chart component to Angular 4 and D3v4
# * Ensure that charts scale-up/down with browser-size
# * Add model objects
# * Integration charts into Dashboard
# * Add service calls to `AnalyticsService`
# * Lay ground-work to also support Aggregate Counters
# * Fix Y-Axis issue for graph-chart (use `yScale(0)` not just `0` for value)
# * Polish Bar-graph
#   - Add basic update + transition-capabilities (Animations)
#   - Add ability to specify the number of bars and width of bars via the Dashboard UI
# * Add JsDoc
# * Add Tests
# * Add domain classes to support changing of the time resolution for aggregate counters
# * Polish the UX around the dependent select-boxes on the Dashboard page
# * Fixes #432
# Old version:
# /**
#  * Retrieves all counters. Will take pagination into account.
#  *
#  * @param detailed If true will request additional counter values from the REST endpoint
#  */
# private getSingleCounter(counterName: string): Observable<Counter> {
#     const requestOptionsArgs: RequestOptionsArgs = HttpUtils.getDefaultRequestOptions();
#     return this.http.get(this.metricsCountersUrl + '/' + counterName, requestOptionsArgs)
#                     .map(response => {
#                       const body = response.json();
#                       console.log('body', body);
#                       return new Counter().deserialize(body);
#                     })
#                     .catch(this.errorHandler.handleError);
# }
# New version:
# /**
#  * Retrieves a single counter.
#  *
#  * @param counterName Name of the counter for which to retrieve details
#  */
# private getSingleCounter(counterName: string): Observable<Counter> {
#         const requestOptionsArgs: RequestOptionsArgs = HttpUtils.getDefaultRequestOptions();
#         return this.http.get(this.metricsCountersUrl + '/' + counterName, requestOptionsArgs)
#                         .map(response => {
#                           const body = response.json();
#                           console.log('body', body);
#                           return new Counter().deserialize(body);
#                         })
#                         .catch(this.errorHandler.handleError);
# }
#
# ###### 24 ######
# URL: https://github.com/counterfactual/monorepo/commit/f5aaf85449e5
# Review: [greenboard] Adds documentation for using the package and creating new scenarios (#2101)
#
# * added prepare(), fixed bad docs
#
# * using prepare()
#
# * added docs for Greenboard
# Old version:
# /**
#  * Opens the Metamask extension page in the current window. It'll automatically
#  * lookup the extension ID from the Extensions Inspector and save the `home`
#  * and `popup` URLs for later usage. If such URLs are already defined,
#  * it'll skip the lookup and navigate to `homeUrl`.
#  */
# async openMetamask() {
#   if (!process.argv.includes("--discover-metamask")) {
#     await this.switchToMetamask();
#     return;
#   }
#
#   if (this.homeUrl && this.popupUrl) {
#     await this.navigateTo(this.homeUrl);
#     return;
#   }
#
#   await this.waitForExtensionsList();
#
#   const backgroundPageUrl = await this.getTextFromElement(
#     METAMASK_EXTENSION_URL_SELECTOR
#   );
#
#   this.homeUrl = backgroundPageUrl.replace(
#     "_generated_background_page",
#     "home"
#   );
#   this.popupUrl = backgroundPageUrl.replace(
#     "_generated_background_page",
#     "popup"
#   );
#
#   await this.navigateTo(this.homeUrl);
#   await this.switchToMetamask();
# }
# New version:
# /**
#  * Only used if the `--discover-metamask` flag is passed to the test runner.
#  *
#  * Opens the Metamask extension page in the current window. It'll automatically
#  * lookup the extension ID from the Extensions Inspector and save the `home`
#  * and `popup` URLs for later usage. If such URLs are already defined,
#  * it'll skip the lookup and navigate to `homeUrl`.
#  */
# async openMetamask() {
#   if (!process.argv.includes("--discover-metamask")) {
#     await this.switchToMetamask();
#     return;
#   }
#
#   if (this.homeUrl && this.popupUrl) {
#     await this.navigateTo(this.homeUrl);
#     return;
#   }
#
#   await this.waitForExtensionsList();
#
#   const backgroundPageUrl = await this.getTextFromElement(
#     METAMASK_EXTENSION_URL_SELECTOR
#   );
#
#   this.homeUrl = backgroundPageUrl.replace(
#     "_generated_background_page",
#     "home"
#   );
#   this.popupUrl = backgroundPageUrl.replace(
#     "_generated_background_page",
#     "popup"
#   );
#
#   await this.navigateTo(this.homeUrl);
#   await this.switchToMetamask();
# }
#
# ###### 25 ######
# URL: https://github.com/jupyterlab/jupyterlab-git/commit/dafc4006d5d3
# Review: Merge PR #630 "Provide UI feedback during Git command execution"
#
# commit 1c2cb43d453d50f2dcf3cb3b55e752f60516de3c
# Author: Frederic Collonval <fcollonval@gmail.com>
# Date:   Fri Jul 24 18:24:42 2020 +0200
#
#     Post Merge branch 'master' corrections
#
# commit 5ec36d7e61c4e4ddc0d94711eeaabf774d18aa98
# Author: Frederic Collonval <fcollonval@gmail.com>
# Date:   Fri Jul 24 17:41:07 2020 +0200
#
#     Merge with master
#
# commit ae71d8d6011875c37b3eb46d307bafff9a44793f
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Sun Jun 14 23:30:28 2020 -0700
#
#     Use finally blocks
#
# commit 2cd0408975dd3859270042173692f73cdde83d90
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Sun Jun 14 23:21:23 2020 -0700
#
#     Reorder properties and methods
#
# commit 9f2d7ca71c40d605cc84ef18fdb54e57dc23686c
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 8 11:08:57 2020 -0700
#
#     Fix response consumption bug
#
# commit e5d86d76500b132fd20ee66598cf8796a866d6d3
# Merge: cab4132 6169af0
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 8 10:33:38 2020 -0700
#
#     Merge branch 'master' of https://github.com/jupyterlab/jupyterlab-git into ui-feedback
#
# commit cab4132664c082e173cda43f34e4df26dfb1ab4f
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 03:30:55 2020 -0700
#
#     Fix broken tests
#
# commit c4f08138e74ad8ddb566c6659882675fb1ebbb8d
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 03:30:02 2020 -0700
#
#     Fix broken tests
#
# commit c132ceda74e56f25cb7e511ea4d8ab1d02e87312
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 03:06:07 2020 -0700
#
#     Add private annotation
#
# commit 28be7d5f7b9b56c34e05f0c9d5de9de3a00d27f5
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 03:04:40 2020 -0700
#
#     Reorder methods
#
# commit f2d40d817f1746d12208d4ec4ab8e27f700158e1
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 02:57:31 2020 -0700
#
#     Refactor to support UI feedback
#
# commit b4d55132b71fead84de9fc550dac2d62fd9719f9
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 02:22:26 2020 -0700
#
#     Fix broken test
#
# commit ab68b01c249521244a619fef49bbf175c58e1505
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 02:13:36 2020 -0700
#
#     Refactor to support toast alerts
#
# commit 99d676614c3c1ef222bafdb9cc07b37b9d08f682
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 02:00:47 2020 -0700
#
#     Refactor to support toast alerts
#
# commit b1d79d6c04c7db857d154f7a86d078970daa7389
# Merge: 3daf4ba 8e79eae
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 01:44:23 2020 -0700
#
#     Merge branch 'master' of https://github.com/jupyterlab/jupyterlab-git into ui-feedback
#
# commit 3daf4ba1afef480c9236f1f8c4387bcc8c2f3398
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 01:33:04 2020 -0700
#
#     Refactor to support log message alerts
#
# commit 2d48ddaecf3d8943f8a729162a9b0c0ac3b7f122
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Mon Jun 1 01:18:06 2020 -0700
#
#     Rename file and refactor into smaller components to support toasts
#
# commit d2037385bf8164ef9640ddebba0e6ac957748fe3
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Wed May 27 16:11:15 2020 -0700
#
#     Refactor to use "toast" notifications
#
# commit 1d5c3647c1eb63e3a33c245836942c41d1800c83
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Wed May 27 16:10:17 2020 -0700
#
#     Add Material UI dep for displaying alert messages within toast notifications
#
# commit e0e6a5e4ee2317a459e03bfe9d3767342acee64b
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Wed May 27 13:34:04 2020 -0700
#
#     Add support for providing UI feedback when committing changes
#
# commit bf5c52ae8a55d6431b673e458b2549db93da24c1
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Wed May 27 10:42:28 2020 -0700
#
#     Fix broken tests
#
# commit 4d849965fe849adaec7c46685302893ccbb28c29
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Wed May 27 10:40:37 2020 -0700
#
#     Add src documentation and rename variables to be in line with project conventions
#
# commit 018444bab5eca5fb6b5298959cdbfd23fbc5ec56
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Tue May 26 17:57:08 2020 -0700
#
#     Fix broken tests
#
# commit 29b99173047ba478ed6343741397eeb80b3dee1f
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Tue May 26 17:54:23 2020 -0700
#
#     Add support for providing feedback when creating a new branch and refactor error handling
#
# commit 126389f38b42fc7b5c4553f5c60bd1476f4e86de
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Tue May 26 17:13:08 2020 -0700
#
#     Provide UI feedback when switching branches
#
# commit b1ec72530b6a743eae3126469d35ab70520d3512
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Tue May 26 16:01:19 2020 -0700
#
#     Add backticks
#
# commit fc2edb09e848eb76e396c2d51ee8321b69f9cf55
# Merge: 62d88de c34abef
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Tue May 26 15:55:28 2020 -0700
#
#     Merge branch 'master' of https://github.com/jupyterlab/jupyterlab-git into ui-feedback
#
# commit 62d88de7904923e27ff6f937eb4b3aad86f5533c
# Author: Athan Reines <kgryte@gmail.com>
# Date:   Tue May 26 15:41:25 2020 -0700
#
#     Document function
#
# commit 1596dee22ac902d9af37f113b6949575eefb5d55
# Author: Athan Reines <kgryte@gmail.com>
# ...
# //      -     quit(0): onBeforeShutdown(0)
# //      -    close(1): onBeforeCloseWindow(1, false)
# //
# // Windows
# //      -     quit(1): onBeforeShutdown(1), onBeforeCloseWindow(1, true)
# //      -     quit(2): onBeforeShutdown(2), onBeforeCloseWindow(2, true), onBeforeCloseWindow(2, true)
# //      -    close(1): onBeforeCloseWindow(2, false)[not last window]
# //      -    close(1): onBeforeCloseWindow(1, false), onBeforeShutdown(0)[last window]
# //      - closeAll(2): onBeforeCloseWindow(2, false), onBeforeCloseWindow(2, false), onBeforeShutdown(0)
# //
# // Linux
# //      -     quit(1): onBeforeShutdown(1), onBeforeCloseWindow(1, true)
# //      -     quit(2): onBeforeShutdown(2), onBeforeCloseWindow(2, true), onBeforeCloseWindow(2, true)
# //      -    close(1): onBeforeCloseWindow(2, false)[not last window]
# //      -    close(1): onBeforeCloseWindow(1, false), onBeforeShutdown(0)[last window]
# //      - closeAll(2): onBeforeCloseWindow(2, false), onBeforeCloseWindow(2, false), onBeforeShutdown(0)
# //
# private onBeforeShutdown(): void {
#         this.shuttingDown = true;
#
#         this.saveWindowsState();
# }
#
# ###### 40 ######
# URL: https://github.com/farcasterxyz/hub-monorepo/commit/f12615d22b2f
# Review: fix(VerificationStore): increase test coverage, change conflict resolution, add docs (#216)
#
# * docs: update verificationStore method docs
#
# * test: add coverage for merge methods
#
# * docs: add class documentation
#
# * docs: more clarifications
# Old version:
# /** Get all VerificationAdd* messages for an fid */
# async getVerificationAddsByUser(fid: Uint8Array): Promise<VerificationAddEthAddressModel[]> {
#   const addsPrefix = VerificationStore.verificationAddsKey(fid);
#   const messageKeys: Buffer[] = [];
#   for await (const [, value] of this._db.iteratorByPrefix(addsPrefix, { keys: false, valueAsBuffer: true })) {
#     messageKeys.push(value);
#   }
#   return MessageModel.getManyByUser<VerificationAddEthAddressModel>(
#     this._db,
#     fid,
#     UserPostfix.VerificationMessage,
#     messageKeys
#   );
# }
# New version:
# /**
#  * Finds all VerificationAdds messages for a user
#  *
#  * @param fid fid of the user who created the signers
#  * @returns the VerificationAddEthAddresses if they exists, throws NotFoundError otherwise
#  */
# async getVerificationAddsByUser(fid: Uint8Array): Promise<VerificationAddEthAddressModel[]> {
#   const addsPrefix = VerificationStore.verificationAddsKey(fid);
#   const messageKeys: Buffer[] = [];
#   for await (const [, value] of this._db.iteratorByPrefix(addsPrefix, { keys: false, valueAsBuffer: true })) {
#     messageKeys.push(value);
#   }
#   return MessageModel.getManyByUser<VerificationAddEthAddressModel>(
#     this._db,
#     fid,
#     UserPostfix.VerificationMessage,
#     messageKeys
#   );
# }
#
# ###### 41 ######
# URL: https://github.com/articodeltd/angular-cesium/commit/7ebc7493e7f0
# Review: - Fixed comments
# - Merged the viewer factory methods by setting options parameter to be optional
# Old version:
# /**
#  * Gets the minimum zoom value
#  * @returns {any}
#  */
# getMinimumZoom() : number {
#     return this.getScene().screenSpaceCameraController.minimumZoomDistance;
# }
# New version:
# /**
#  * Gets the minimum zoom value in meters
#  * @returns {any}
#  */
# getMinimumZoom() : number {
#     return this.getScene().screenSpaceCameraController.minimumZoomDistance;
# }
#
# ###### 42 ######
# URL: https://github.com/bitmovin/bitmovin-player-ui/commit/6618d3420121
# Review: improve and fix typos in documentation
# Old version:
# /**
#  * Resets the navigation stack and navigate to the root page and make it visible
#  */
# popToRootSettingsPanelPage(): void {
#   this.resetNavigation();
# }
# New version:
# /**
#  * Resets the navigation stack by navigating back to the root page and displaying it.
#  */
# popToRootSettingsPanelPage(): void {
#   this.resetNavigation();
# }
#
# ###### 43 ######
# URL: https://github.com/firebase/firebase-admin-node/commit/94dd7c3efb9f
# Review: chore: Enabled tsdoc error checking (#1459)
#
# * chore: Enabled tsdoc error checking
#
# * fix: Fixing a lint error
#
# * fix: Minor internal doc comment updates
#
# * fix: Updating doc comment
# Old version:
# /**
#  * Creates a new {@link appCheck.AppCheckToken `AppCheckToken`} that can be sent
#  * back to a client.
#  *
#  * @param appId The app ID to use as the JWT app_id.
#  * @param options Optional options object when creating a new App Check Token.
#  *
#  * @returns A promise that fulfills with a `AppCheckToken`.
#  */
# public createToken(appId: string, options?: AppCheckTokenOptions): Promise<AppCheckToken> {
#   return this.tokenGenerator.createCustomToken(appId, options)
#     .then((customToken) => {
#       return this.client.exchangeToken(customToken, appId);
#     });
# }
# New version:
# /**
#  * Creates a new {@link AppCheckToken} that can be sent
#  * back to a client.
#  *
#  * @param appId - The app ID to use as the JWT app_id.
#  * @param options - Optional options object when creating a new App Check Token.
#  *
#  * @returns A promise that fulfills with a `AppCheckToken`.
#  */
# public createToken(appId: string, options?: AppCheckTokenOptions): Promise<AppCheckToken> {
#   return this.tokenGenerator.createCustomToken(appId, options)
#     .then((customToken) => {
#       return this.client.exchangeToken(customToken, appId);
#     });
# }
#
# ###### 44 ######
# URL: https://github.com/heremaps/harp.gl/commit/ab9bf5be20ce
# Review: HARP-4531: Fix getLastFrameStatistics to return latest frame value
#
#   RingBuffer implementation is actually FIFO, comments updated.
#   Added "bottom" method for retrieving latest element, expanded test coverage.
#
# Signed-off-by: Craig Black <craig.black@here.com>
# Old version:
# /**
#  * Obtains the latest element (LIFO) without removing it. Throws an exception if a buffer is
#  * empty. Before calling this method, make sure that `size > 0`.
#  */
# get top(): T {
#     if (this.size === 0) {
#         throw new Error("Ringbuffer underrun");
#     }
#
#     return this.buffer[this.tail];
# }
# New version:
# /**
#  * Obtains the oldest element (FIFO) without removing it. Throws an exception if a buffer is
#  * empty. Before calling this method, make sure that `size > 0`.
#  */
# get top(): T {
#     if (this.size === 0) {
#         throw new Error("Ringbuffer underrun");
#     }
#
#     return this.buffer[this.tail];
# }
#
# ###### 45 ######
# URL: https://github.com/informalsystems/quint/commit/9287ae2a42cf
# Review: Mode checker fix for polymorphic operators (#447)
#
# * Use same mode checker strat for all effects
#
# * Fix bug in effect substitutions
#
# * Fix minor issues on documentation
#
# * Update mode on example affected by the fixed bug
#
# * Update tntc/src/effects/modeChecker.ts
#
# Co-authored-by: Igor Konnov <igor@informal.systems>
# Old version:
# // Compile an expression, evaluate it, convert to TlaEx, then to a string,
# // compare the result. This is the easiest path to test the results.
# function assertResultAsString(input: string, expected: string | undefined) {
#   const moduleText = `module __runtime { val __expr = ${input} }`
#   const context = compile(moduleText).values
#   const value = context.get(kindName('callable', '__expr'))
#   if (value === undefined) {
#     assert(false, `Missing value for ${input}`)
#   } else {
#     const result = value
#       .eval()
#       .map(r => r.toTntEx())
#       .map(expressionToString)
#       .map(s => assert(s === expected, `Expected ${expected}, found ${s}`))
#     if (result.isNone()) {
#       assert(expected === undefined, `Expected ${expected}, found undefined`)
#     }
#   }
# }
# New version:
# // Compile an expression, evaluate it, convert to TntEx, then to a string,
# // compare the result. This is the easiest path to test the results.
# function assertResultAsString(input: string, expected: string | undefined) {
#   const moduleText = `module __runtime { val __expr = ${input} }`
#   const context = compile(moduleText).values
#   const value = context.get(kindName('callable', '__expr'))
#   if (value === undefined) {
#     assert(false, `Missing value for ${input}`)
#   } else {
#     const result = value
#       .eval()
#       .map(r => r.toTntEx())
#       .map(expressionToString)
#       .map(s => assert(s === expected, `Expected ${expected}, found ${s}`))
#     if (result.isNone()) {
#       assert(expected === undefined, `Expected ${expected}, found undefined`)
#     }
#   }
# }
#
# ###### 46 ######
# URL: https://github.com/MetaMask/core/commit/c7fd7db9ffe6
# Review: Add default type and timestamps to approval controller (#309)
#
# * Add approval controller request times
#
# * Fix ApprovalInfo interface documentation
#
# * Fix some docstrings
#
# * Remove NO_TYPE, add consumer-specifed default type
#
# * Rename ApprovalInfo interface to Approval
#
# * Fix some docstrings
#
# * Fix _validateAddParams bugs
# Old version:
# /**
#  * Checks whether there are any pending approvals associated with the given
#  * origin.
#  *
#  * @param origin - The origin to check.
#  * @returns True if the origin has no pending approvals, false otherwise.
#  */
# private _isEmptyOrigin(origin: string): boolean {
#   return !this._origins.get(origin)?.size;
# }
# New version:
# /**
#  * Checks whether there are any approvals associated with the given
#  * origin.
#  *
#  * @param origin - The origin to check.
#  * @returns True if the origin has no approvals, false otherwise.
#  */
# private _isEmptyOrigin(origin: string): boolean {
#   return !this._origins.get(origin)?.size;
# }
#
# ###### 47 ######
# URL: https://github.com/harmonyland/harmony/commit/fe6930c06523
# Review: miner grammer/typo fixes is comments. Changed all comments I can find to consider method as a singular noun, tho I might missed a few comments
# Old version:
# /** Check if every value/key in Collection satisfy callback */
# every(callback: (value: V, key: K) => boolean): boolean {
#   for (const key of this.keys()) {
#     const value = this.get(key) as V
#     if (!callback(value, key)) return false
#   }
#   return true
# }
# New version:
# /** Check if every value/key in Collection satisfies callback */
# every(callback: (value: V, key: K) => boolean): boolean {
#   for (const key of this.keys()) {
#     const value = this.get(key) as V
#     if (!callback(value, key)) return false
#   }
#   return true
# }
#
# ###### 48 ######
# URL: https://github.com/microsoft/iot-cardboard-js/commit/9eb874552d6c
# Review: feat: Twin alias in behavior (#316)
#
# * initial twin alias tab implementation for behavior
#
# * callout ui added for adding from existing twin aliases
#
# * linting fixes
#
# * elements are updated when twin aliases set from behavior
#
# * add bahvior onadd handler fixed
#
# * import fix for test build
#
# * rename and style type fix
#
# * available aliases from elements in the behavior added for add twin alias callout in addition to aliases from other behaviors
#
# * edit twin alias logic fixed
#
# * bug fix for adding new alias to already existing list for an element
#
# * icon change
#
# * fix bug for UI change flow not waiting for behavior update and disabled alias change after creation
#
# * ui tests fix
#
# * fixes for tab click ui tests
#
# * moved methods to utils and refactored translations
#
# * changed folder structure for twin alias related subcomponents and revised utils functions and adapter methods to get aliased twins properties as well or filtering just for linked twin properties with a flag
#
# * fix for property list for intellisense, will support twin aliases soon
#
# * hooked aliased twins to intellisense and changed adapter and utility methods to support it accordingly
#
# * fix for build test
#
# * change for ui component test error
#
# * fix for ui tests
#
# * fixed error method not respect await to wait the promise to resolve
#
# * added CardboardBasicList and fixed styling for twin search dropdown and removed some styles
#
# * actual fixes for twin search dropdown styling and one CR fix
#
# * CR fixes, from spread to deepcopy changes need to be tested
#
# * fixed cascading effects of spread to deepcopy changes, need to test all cases though
#
# * more CR fixes for stylings and commenting and fixed the return not waiting for await to resolve in mock adapter
#
# * more CR fix for using config utils
#
# * made the behavior twin property related hooks separate due to different return types
#
# * test stories added for Twins tab
#
# * restore icon to widget builder page
#
# * added stories for twins tab, we can add stories for twin alias form later
#
# Co-authored-by: Matt Darsney <matdar@microsoft.com>
# Old version:
# /**
#  * Gets the list of all the active properties from the provided linked twins
#  * Returns them with the Alias as a prefix. ex: LinkedTwin.MyProperty
#  * @param twins List of twins the get the properties from
#  * @returns list of properties with the alias prefixed (ex: LinkedTwin.MyProperty)
#  */
# static getPropertyNamesWithAliasFromTwins(twins: Record<string, any>) {
#     const properties = new Set<string>();
#     for (const alias in twins) {
#         const twin = twins[alias];
#         const split = alias.split('.');
#         const name = split.length ? split[0] : alias;
#         for (const prop in twin) {
#             if (prop.substring(0, 1) !== '$' || prop === '$dtId') {
#                 properties.add(`${name}.${prop}`);
#             }
#         }
#     }
#     return Array.from(properties.values()).sort();
# }
# New version:
# /**
#  * Gets the list of all (union of) the active properties from the provided linked twins
#  * Returns them with the Alias as a prefix. ex: LinkedTwin.MyProperty
#  * @param twins List of twins the get the properties from
#  * @returns list of properties with the alias prefixed (ex: LinkedTwin.MyProperty)
#  */
# static getPropertyNamesWithAliasFromTwins(twins: Record<string, any>) {
#     const properties = new Set<string>();
#     for (const alias in twins) {
#         const twin = twins[alias];
#         const split = alias.split('.');
#         const name = split.length ? split[0] : alias;
#         for (const prop in twin) {
#             if (prop.substring(0, 1) !== '$' || prop === '$dtId') {
#                 properties.add(`${name}.${prop}`);
#             }
#         }
#     }
#     return Array.from(properties.values()).sort();
# }
#
# ###### 49 ######
# URL: https://github.com/Uniswap/v3-sdk/commit/2c8aa3a65383
# Review: Comment Updates (#45)
#
# * updates various sdk comments`
#
# * cleanup
#
# * Fix code style issues with Prettier
#
# * update re comments
#
# * Fix code style issues with Prettier
#
# * updates re comments
# Old version:
# /**
#  * Constructs an exact out trade with the given amount out and route
#  * @param route route of the exact out trade
#  * @param amountOut the amount returned by the trade
#  */
# public static async exactOut<TInput extends Currency, TOutput extends Currency>(
#   route: Route<TInput, TOutput>,
#   amountOut: CurrencyAmount<TOutput>
# ): Promise<Trade<TInput, TOutput, TradeType.EXACT_OUTPUT>> {
#   return Trade.fromRoute(route, amountOut, TradeType.EXACT_OUTPUT)
# }
# New version:
# /**
#  * Constructs an exact out trade with the given amount out and route
#  * @template TInput The input token, either Ether or an ERC-20
#  * @template TOutput The output token, either Ether or an ERC-20
#  * @param route The route of the exact out trade
#  * @param amountOut The amount returned by the trade
#  * @returns The exact out trade
#  */
# public static async exactOut<TInput extends Currency, TOutput extends Currency>(
#   route: Route<TInput, TOutput>,
#   amountOut: CurrencyAmount<TOutput>
# ): Promise<Trade<TInput, TOutput, TradeType.EXACT_OUTPUT>> {
#   return Trade.fromRoute(route, amountOut, TradeType.EXACT_OUTPUT)
# }
#
# ###### 50 ######
# URL: https://github.com/microsoft/ApplicationInsights-node.js/commit/dd5684ce20c4
# Review: edits to comments in applicationinsights.ts (#223)
#
# * edits to comments
#
# * fixup! edits to comments
# Old version:
# /**
#  * Enables verbose debug logging
#  * @returns {ApplicationInsights} this class
#  */
# public static enableVerboseLogging(enableWarningLogging = true) {
#     Logging.enableDebug = true;
#     Logging.disableWarnings = !enableWarningLogging;
#     return ApplicationInsights;
# }
# New version:
# /**
#  * Enables debug and warning logging for AppInsights itself.
#  * @param enableWarningLogging also show warnings
#  * @returns {ApplicationInsights} this class
#  */
# public static enableVerboseLogging(enableWarningLogging = true) {
#     Logging.enableDebug = true;
#     Logging.disableWarnings = !enableWarningLogging;
#     return ApplicationInsights;
# }
